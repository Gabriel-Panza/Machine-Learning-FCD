# %%
import nibabel as nib
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from tqdm import tqdm
from tensorflow.keras import layers, models, callbacks, metrics, Input, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from skimage.transform import rotate
import random
# Out:
# WARNING:tensorflow:From c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Função que carrega os dados com pares de imagens
def load_data_with_pairs(folder):
    if not os.path.exists(folder):
        print(f"A pasta {folder} não existe.")
        return {}, {}, {}, {}, {}

    images_by_group = {}
    mask_by_group = {}
    patient_ids = []

    # Itera sobre os pacientes no diretório
    for patient_id in tqdm(os.listdir(folder), desc="Carregamento de arquivos NIfTI..."):
        patient_path = os.path.join(folder, patient_id)

        areas_image = ["left", "right"]
        areas_mask = ["lesion_left", "lesion_right"]
        side_path_left = os.path.join(patient_path, areas_image[0])
        side_path_right = os.path.join(patient_path, areas_image[1])
        lesion_path_left = os.path.join(patient_path, areas_mask[0])
        lesion_path_right = os.path.join(patient_path, areas_mask[1])

        if patient_id not in images_by_group:
            images_by_group[patient_id] = {}
        if patient_id not in mask_by_group:
            mask_by_group[patient_id] = {}
        for type_image, type_mask in zip(areas_image, areas_mask):
            if type_image not in images_by_group[patient_id]:
                images_by_group[patient_id][type_image] = []
            if type_mask not in mask_by_group[patient_id]:
                mask_by_group[patient_id][type_mask] = []
            
            # Carrega as imagens e máscaras do lado esquerdo
            for patch_id, mask_id in zip(os.listdir(side_path_left), os.listdir(lesion_path_left)):
                img_path= os.path.join(side_path_left, patch_id)
                mask_path = os.path.join(lesion_path_left, mask_id)
                for img_path_left, mask_path_left in zip(os.listdir(img_path), os.listdir(mask_path)):
                    image_data_left = nib.load(os.path.join(img_path, img_path_left)).get_fdata()
                    mask_data_left = nib.load(os.path.join(mask_path, mask_path_left)).get_fdata()

                    images_by_group[patient_id][type_image].append(image_data_left)
                    mask_by_group[patient_id][type_mask].append(mask_data_left)

            # Carrega as imagens e máscaras do lado direito
            for patch_id, mask_id in zip(os.listdir(side_path_right), os.listdir(lesion_path_right)):
                img_path = os.path.join(side_path_right, patch_id)
                mask_path = os.path.join(lesion_path_right, mask_id)
                for img_path_right, mask_path_right in zip(os.listdir(img_path), os.listdir(mask_path)):
                    image_data_right = nib.load(os.path.join(img_path, img_path_right)).get_fdata()
                    mask_data_right = nib.load(os.path.join(mask_path, mask_path_right)).get_fdata()

                    images_by_group[patient_id][type_image].append(image_data_right)
                    mask_by_group[patient_id][type_mask].append(mask_data_right)
        patient_ids.append(patient_id)

    # Estruturas para armazenar pares de imagens e máscaras (esquerdo e direito (contralateral))
    images_left = {}
    images_right = {}
    mask_left = {}
    mask_right = {}
    labels_pair = {}

    for patient_id in images_by_group.keys():
        images_left[patient_id] = []
        images_right[patient_id] = []
        mask_left[patient_id] = []
        mask_right[patient_id] = []
        labels_pair[patient_id] = []
        
        for patch_left_image, mask_left_image, patch_right_image, mask_right_image in zip(images_by_group[patient_id][list(images_by_group[patient_id].keys())[0]], mask_by_group[patient_id][list(mask_by_group[patient_id].keys())[0]], images_by_group[patient_id][list(images_by_group[patient_id].keys())[1]], mask_by_group[patient_id][list(mask_by_group[patient_id].keys())[1]]):
            images_left[patient_id].append(patch_left_image)
            images_right[patient_id].append(patch_right_image)
            mask_left[patient_id].append(mask_left_image)
            mask_right[patient_id].append(mask_right_image)
            
            # Determina se há lesão na máscara da imagem esquerda e na contralateral direita
            has_lesion_left  = np.any(mask_left_image >= 0.5)
            has_lesion_right = np.any(mask_right_image >= 0.5)
            
            # Define o label para o par com base na presença de lesão
            if has_lesion_left == False and has_lesion_right == False:
                labels_pair[patient_id].append(0)
            else:
                labels_pair[patient_id].append(1)

    print(f"Total de pacientes: {len(patient_ids)}")
    for patient_id, labels in labels_pair.items():
        print(f"Paciente {patient_id}: Total de pares de recortes: {len(labels)}")

    return images_left, images_right, labels_pair, mask_left, mask_right

# %%
# Função de data augmentation revisada
def augment_data(images_original, images_opposite, labels, augment_factor=1):
    augmented_images_original = []
    augmented_images_opposite = []
    augmented_labels = []

    for i in range(len(labels)):
        original = images_original[i]
        opposite = images_opposite[i]
        label = labels[i]

        augmented_images_original.append(original)
        augmented_images_opposite.append(opposite)
        augmented_labels.append(label)

        for _ in range(augment_factor - 1):
            angle = random.uniform(-15, 15)
            augmented_original = rotate(original, angle, mode='wrap')
            augmented_opposite = rotate(opposite, angle, mode='wrap')
            
            augmented_images_original.append(augmented_original)
            augmented_images_opposite.append(augmented_opposite)
            augmented_labels.append(label)

    # Converter listas em arrays numpy após garantir a homogeneidade de forma e tipo
    return augmented_images_original, augmented_images_opposite, augmented_labels

# %%
# Função para filtrar as imagens por paciente
def select_by_patients(patients, all_images_original, all_images_opposite, all_labels):
    selected_images_original = []
    selected_images_opposite = []
    selected_labels = []
    
    for patient in patients:
        if patient in all_images_original and patient in all_images_opposite:
            selected_images_original.extend(all_images_original[patient])
            selected_images_opposite.extend(all_images_opposite[patient])
            selected_labels.extend(all_labels[patient])
        else:
            print(f"Paciente {patient} não encontrado em uma das listas de imagens.")
    
    return (selected_images_original), (selected_images_opposite), selected_labels

# %%
# Função para preparar os dados para treino, validação e teste
def prepare_data_for_training_balanced(images_left, images_right, labels_pair, mask_left, mask_right, train_size=0.7, validation_size=0.2, test_size=0.1, augment_factor=1):
    balanced_images_original = {}
    balanced_images_opposite = {}
    balanced_labels = {}
    balanced_mask_original = {}
    balanced_mask_opposite = {}

    for patient_id in images_left:
        class_1_labels = []
        class_0_labels = []
        class_1_left = {}
        class_0_left = {}
        class_1_right = {}
        class_0_right = {}
        class_1_mask_left = {}
        class_0_mask_left = {}
        class_1_mask_right = {}
        class_0_mask_right = {}
        
        class_1_left[patient_id] = []
        class_0_left[patient_id] = []
        class_1_right[patient_id] = []
        class_0_right[patient_id] = []
        class_1_mask_left[patient_id] = []
        class_0_mask_left[patient_id] = []
        class_1_mask_right[patient_id] = []
        class_0_mask_right[patient_id] = []
        index = 0
        
        # Iterar sobre os patches e dividir as classes 0 e 1 com base nas labels
        for label in labels_pair[patient_id]:
            image_left = (images_left[patient_id])[index]
            image_right = (images_right[patient_id])[index]
            mask_image_left = (mask_left[patient_id])[index]
            mask_image_right = (mask_right[patient_id])[index]
            index += 1
            
            if label == 1:
                class_1_labels.append(label)
                class_1_left[patient_id].append(image_left)
                class_1_right[patient_id].append(image_right)
                class_1_mask_left[patient_id].append(mask_image_left)
                class_1_mask_right[patient_id].append(mask_image_right)
            else:
                class_0_labels.append(label)
                class_0_left[patient_id].append(image_left)
                class_0_right[patient_id].append(image_right)
                class_0_mask_left[patient_id].append(mask_image_left)
                class_0_mask_right[patient_id].append(mask_image_right)
        
        class_1_count = len(class_1_labels)
        print(f"Paciente {patient_id}: Total de pares de recortes com labels 1: {class_1_count}")

        # Fazer undersampling da classe majoritária (label 0) para igualar ao número de exemplos da classe 1
        class_0_count = len(class_0_labels)
        if class_0_count > class_1_count:
            sampled_class_0_slices_left = (class_0_left[patient_id])[:class_1_count]
            sampled_class_0_slices_right = (class_0_right[patient_id])[:class_1_count]
            class_0_original_modified = {}
            class_0_original_modified[patient_id] = []
            class_0_opposite_modified = {}
            class_0_opposite_modified[patient_id] = []
            sampled_class_0_mask_left = (class_0_mask_left[patient_id])[:class_1_count]
            sampled_class_0_mask_right = (class_0_mask_right[patient_id])[:class_1_count]
            class_0_mask_original_modified = {}
            class_0_mask_original_modified[patient_id] = []
            class_0_mask_opposite_modified = {}
            class_0_mask_opposite_modified[patient_id] = []
            
            for left_image, left_mask in zip(sampled_class_0_slices_left, sampled_class_0_mask_left):
                class_0_original_modified[patient_id].append(left_image)
                class_0_mask_original_modified[patient_id].append(left_mask)
            for right_image, right_mask in zip(sampled_class_0_slices_right, sampled_class_0_mask_right):
                class_0_opposite_modified[patient_id].append(right_image)
                class_0_mask_opposite_modified[patient_id].append(right_mask)
            class_0_labels = [0] * class_1_count

        balanced_images_original[patient_id] = list(class_1_left[patient_id]) + list(class_0_original_modified[patient_id])
        balanced_images_opposite[patient_id] = list(class_1_right[patient_id]) + list(class_0_opposite_modified[patient_id])
        balanced_labels[patient_id] = class_1_labels + class_0_labels
        balanced_mask_original[patient_id] = list(class_1_mask_left[patient_id]) + list(class_0_mask_original_modified[patient_id])
        balanced_mask_opposite[patient_id] = list(class_1_mask_right[patient_id]) + list(class_0_mask_opposite_modified[patient_id])

    for patient_id, images in balanced_images_original.items():
        print(f"Paciente {patient_id}: Total de pares de recortes (label 1 + label 0): {len(images)}")
        
    # Separar os dados por conjunto (treino, validação, teste)
    patients = list(set(balanced_labels.keys()))
    train_patients, valtest_patients = train_test_split(patients, train_size = train_size, random_state=42)
    val_patients, test_patients = train_test_split(valtest_patients, train_size = validation_size / (validation_size + test_size), random_state=42)
        
    X_train_original, X_train_opposite, y_train = select_by_patients(train_patients, balanced_images_original, balanced_images_opposite, balanced_labels)
    X_val_original, X_val_opposite, y_val = select_by_patients(val_patients, balanced_images_original, balanced_images_opposite, balanced_labels)
    X_test_original, X_test_opposite, y_test = select_by_patients(test_patients, balanced_images_original, balanced_images_opposite, balanced_labels)
    mask_test_original, mask_test_opposite, _ = select_by_patients(test_patients, balanced_mask_original, balanced_mask_opposite, balanced_labels)

    # Aplicar data augmentation nas imagens
    # X_train_original_, X_train_opposite_, y_train = augment_data(X_train_original, X_train_opposite, y_train, augment_factor=augment_factor)
    # X_val_original_, X_val_opposite_, y_val = augment_data(X_val_original, X_val_opposite, y_val, augment_factor=augment_factor)
    # X_test_original_, X_test_opposite_, y_test = augment_data(X_test_original, X_test_opposite, y_test, augment_factor=augment_factor)
    
    X_train_original = [img for img in X_train_original if len(img)>0 and img is not []]
    X_train_opposite = [img for img in X_train_opposite if len(img)>0 and img is not []]

    print(f"Total de pares de recortes no treino ({augment_factor}*{train_patients}) com label 1: {y_train.count(1)}")
    print(f"Total de pares de recortes no treino ({augment_factor}*{train_patients}) com label 0: {y_train.count(0)}")
    print(f"Total de pares de recortes na validação ({augment_factor}*{val_patients}) com label 1: {y_val.count(1)}")
    print(f"Total de pares de recortes na validação ({augment_factor}*{val_patients}) com label 0: {y_val.count(0)}")
    print(f"Total de pares de recortes no teste com ({augment_factor}*{test_patients}) label 1: {y_test.count(1)}")
    print(f"Total de pares de recortes no teste com ({augment_factor}*{test_patients}) label 0: {y_test.count(0)}")
    
    return np.array(X_train_original), np.array(X_train_opposite), np.array(X_val_original), np.array(X_val_opposite), np.array(X_test_original), np.array(X_test_opposite), np.array(y_train), np.array(y_val), np.array(y_test), np.array(mask_test_original), np.array(mask_test_opposite)

# %%
# Função para construir o modelo CNN 2D
def build_cnn_model(input_shape):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3,3), data_format="channels_last", activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Dropout(0.3))
        
    model.add(layers.Conv2D(64, (3,3), data_format="channels_last", activation='relu'))
    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Dropout(0.3))
    
    model.add(layers.Conv2D(128, (3, 3), data_format="channels_last", activation='relu'))
    model.add(layers.MaxPooling2D((2, 2))) 
    model.add(layers.Dropout(0.3)) 
    
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.3))

    return model

def attention_layer(inputs): 
    attention_probs = layers.Dense(inputs.shape[-1], activation='softmax', name='attention_probs')(inputs) 
    attention_mul = layers.Multiply()([inputs, attention_probs]) 
    return attention_mul

# %%
# Função para construir a rede siamesa
def build_siamese_model(input_shape_original, input_shape_opposite):
    input_original = Input(shape=input_shape_original)
    input_opposite = Input(shape=input_shape_opposite)

    cnn_model = build_cnn_model(input_shape_original)
    output_original = cnn_model(input_original)
    cnn_model_opposite = build_cnn_model(input_shape_opposite)
    output_opposite = cnn_model_opposite(input_opposite)

    # Aplicar atenção nas saídas das CNNs 
    attention_output_original = attention_layer(output_original) 
    attention_output_opposite = attention_layer(output_opposite)
    
    # Concatenar as duas saídas (Lado esquerdo + Contra-lateral)
    concatenated = layers.Concatenate()([attention_output_original, attention_output_opposite])
    concatenated = layers.BatchNormalization()(concatenated)
    
    output = layers.Dense(1, activation='sigmoid')(concatenated)
    
    siamese_model = Model(inputs=[attention_output_original, attention_output_opposite], outputs=output)
    siamese_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy', metrics.Precision(name="precision"), metrics.Recall(name="recall")])

    return siamese_model

# %%
def plot_training_history(history):
    plt.figure(figsize=(12, 4))

    # Plot Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Graphic')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy Graphic')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# %%
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.show()

# %%
input_folder = 'Contralateral'

# Carregar os dados
X_left, X_right, y, mask_left, mask_right = load_data_with_pairs(input_folder)
# Out:
# Carregamento de arquivos NIfTI...: 100%|██████████| 41/41 [09:17<00:00, 13.59s/it]
# Total de pacientes: 41
# Paciente sub-00H10: Total de pares de recortes: 792
# Paciente sub-02A13: Total de pares de recortes: 824
# Paciente sub-03C08: Total de pares de recortes: 744
# Paciente sub-06C09: Total de pares de recortes: 792
# Paciente sub-16E03: Total de pares de recortes: 864
# Paciente sub-16G09: Total de pares de recortes: 816
# Paciente sub-16I12: Total de pares de recortes: 824
# Paciente sub-19F09: Total de pares de recortes: 848
# Paciente sub-19G04: Total de pares de recortes: 792
# Paciente sub-22F14: Total de pares de recortes: 824
# Paciente sub-25B08: Total de pares de recortes: 864
# Paciente sub-26B09: Total de pares de recortes: 792
# Paciente sub-29D03: Total de pares de recortes: 784
# Paciente sub-31F07: Total de pares de recortes: 800
# Paciente sub-34J06: Total de pares de recortes: 496
# Paciente sub-35E12: Total de pares de recortes: 800
# Paciente sub-36K02: Total de pares de recortes: 824
# Paciente sub-41D08: Total de pares de recortes: 760
# Paciente sub-42B05: Total de pares de recortes: 808
# Paciente sub-44H05: Total de pares de recortes: 856
# Paciente sub-51C05: Total de pares de recortes: 872
# Paciente sub-52K04: Total de pares de recortes: 816
# Paciente sub-54K08: Total de pares de recortes: 816
# Paciente sub-56E13: Total de pares de recortes: 768
# Paciente sub-57D04: Total de pares de recortes: 816
# Paciente sub-59E09: Total de pares de recortes: 760
# Paciente sub-59G00: Total de pares de recortes: 720
# Paciente sub-60G06: Total de pares de recortes: 832
# Paciente sub-60K04: Total de pares de recortes: 728
# Paciente sub-71C07: Total de pares de recortes: 752
# Paciente sub-72I02: Total de pares de recortes: 840
# Paciente sub-72K02: Total de pares de recortes: 888
# Paciente sub-76E02: Total de pares de recortes: 872
# Paciente sub-76J09: Total de pares de recortes: 736
# Paciente sub-79H07: Total de pares de recortes: 688
# Paciente sub-83K08: Total de pares de recortes: 800
# Paciente sub-85I05: Total de pares de recortes: 856
# Paciente sub-86G08: Total de pares de recortes: 832
# Paciente sub-87G01: Total de pares de recortes: 848
# Paciente sub-89A03: Total de pares de recortes: 848
# Paciente sub-90K10: Total de pares de recortes: 816

# %%
# Preparar dados para treino, teste e validação
X_train_left, X_train_right, X_valid_left, X_valid_right, X_test_left, X_test_right, y_train, y_valid, y_test, mask_left_test, mask_right_test = prepare_data_for_training_balanced(X_left, X_right, y, mask_left, mask_right, train_size=0.7, validation_size=0.2, test_size=0.1)

# Adiciono camada de cor
X_train_left = np.expand_dims(X_train_left, axis=-1)
X_train_right = np.expand_dims(X_train_right, axis=-1)
X_valid_left = np.expand_dims(X_valid_left, axis=-1)
X_valid_right = np.expand_dims(X_valid_right, axis=-1)
X_test_left = np.expand_dims(X_test_left, axis=-1)
X_test_right = np.expand_dims(X_test_right, axis=-1)

# Normalizo os dados
X_train_left /= 255
X_train_right /= 255
X_valid_left /= 255
X_valid_right /= 255
X_test_left /= 255
X_test_right /= 255
# Out:
# Paciente sub-00H10: Total de pares de recortes com labels 1: 94
# Paciente sub-02A13: Total de pares de recortes com labels 1: 126
# Paciente sub-03C08: Total de pares de recortes com labels 1: 46
# Paciente sub-06C09: Total de pares de recortes com labels 1: 38
# Paciente sub-16E03: Total de pares de recortes com labels 1: 36
# Paciente sub-16G09: Total de pares de recortes com labels 1: 48
# Paciente sub-16I12: Total de pares de recortes com labels 1: 30
# Paciente sub-19F09: Total de pares de recortes com labels 1: 64
# Paciente sub-19G04: Total de pares de recortes com labels 1: 74
# Paciente sub-22F14: Total de pares de recortes com labels 1: 66
# Paciente sub-25B08: Total de pares de recortes com labels 1: 147
# Paciente sub-26B09: Total de pares de recortes com labels 1: 66
# Paciente sub-29D03: Total de pares de recortes com labels 1: 66
# Paciente sub-31F07: Total de pares de recortes com labels 1: 34
# Paciente sub-34J06: Total de pares de recortes com labels 1: 36
# Paciente sub-35E12: Total de pares de recortes com labels 1: 60
# Paciente sub-36K02: Total de pares de recortes com labels 1: 94
# Paciente sub-41D08: Total de pares de recortes com labels 1: 156
# Paciente sub-42B05: Total de pares de recortes com labels 1: 40
# Paciente sub-44H05: Total de pares de recortes com labels 1: 26
# Paciente sub-51C05: Total de pares de recortes com labels 1: 65
# Paciente sub-52K04: Total de pares de recortes com labels 1: 32
# Paciente sub-54K08: Total de pares de recortes com labels 1: 270
# Paciente sub-56E13: Total de pares de recortes com labels 1: 72
# Paciente sub-57D04: Total de pares de recortes com labels 1: 150
# Paciente sub-59E09: Total de pares de recortes com labels 1: 81
# Paciente sub-59G00: Total de pares de recortes com labels 1: 48
# Paciente sub-60G06: Total de pares de recortes com labels 1: 201
# Paciente sub-60K04: Total de pares de recortes com labels 1: 54
# Paciente sub-71C07: Total de pares de recortes com labels 1: 207
# Paciente sub-72I02: Total de pares de recortes com labels 1: 60
# Paciente sub-72K02: Total de pares de recortes com labels 1: 91
# Paciente sub-76E02: Total de pares de recortes com labels 1: 62
# Paciente sub-76J09: Total de pares de recortes com labels 1: 66
# Paciente sub-79H07: Total de pares de recortes com labels 1: 218
# Paciente sub-83K08: Total de pares de recortes com labels 1: 26
# Paciente sub-85I05: Total de pares de recortes com labels 1: 165
# Paciente sub-86G08: Total de pares de recortes com labels 1: 50
# Paciente sub-87G01: Total de pares de recortes com labels 1: 82
# Paciente sub-89A03: Total de pares de recortes com labels 1: 64
# Paciente sub-90K10: Total de pares de recortes com labels 1: 144
# Paciente sub-00H10: Total de pares de recortes (label 1 + label 0): 188
# Paciente sub-02A13: Total de pares de recortes (label 1 + label 0): 252
# Paciente sub-03C08: Total de pares de recortes (label 1 + label 0): 92
# Paciente sub-06C09: Total de pares de recortes (label 1 + label 0): 76
# Paciente sub-16E03: Total de pares de recortes (label 1 + label 0): 72
# Paciente sub-16G09: Total de pares de recortes (label 1 + label 0): 96
# Paciente sub-16I12: Total de pares de recortes (label 1 + label 0): 60
# Paciente sub-19F09: Total de pares de recortes (label 1 + label 0): 128
# Paciente sub-19G04: Total de pares de recortes (label 1 + label 0): 148
# Paciente sub-22F14: Total de pares de recortes (label 1 + label 0): 132
# Paciente sub-25B08: Total de pares de recortes (label 1 + label 0): 294
# Paciente sub-26B09: Total de pares de recortes (label 1 + label 0): 132
# Paciente sub-29D03: Total de pares de recortes (label 1 + label 0): 132
# Paciente sub-31F07: Total de pares de recortes (label 1 + label 0): 68
# Paciente sub-34J06: Total de pares de recortes (label 1 + label 0): 72
# Paciente sub-35E12: Total de pares de recortes (label 1 + label 0): 120
# Paciente sub-36K02: Total de pares de recortes (label 1 + label 0): 188
# Paciente sub-41D08: Total de pares de recortes (label 1 + label 0): 312
# Paciente sub-42B05: Total de pares de recortes (label 1 + label 0): 80
# Paciente sub-44H05: Total de pares de recortes (label 1 + label 0): 52
# Paciente sub-51C05: Total de pares de recortes (label 1 + label 0): 130
# Paciente sub-52K04: Total de pares de recortes (label 1 + label 0): 64
# Paciente sub-54K08: Total de pares de recortes (label 1 + label 0): 540
# Paciente sub-56E13: Total de pares de recortes (label 1 + label 0): 144
# Paciente sub-57D04: Total de pares de recortes (label 1 + label 0): 300
# Paciente sub-59E09: Total de pares de recortes (label 1 + label 0): 162
# Paciente sub-59G00: Total de pares de recortes (label 1 + label 0): 96
# Paciente sub-60G06: Total de pares de recortes (label 1 + label 0): 402
# Paciente sub-60K04: Total de pares de recortes (label 1 + label 0): 108
# Paciente sub-71C07: Total de pares de recortes (label 1 + label 0): 414
# Paciente sub-72I02: Total de pares de recortes (label 1 + label 0): 120
# Paciente sub-72K02: Total de pares de recortes (label 1 + label 0): 182
# Paciente sub-76E02: Total de pares de recortes (label 1 + label 0): 124
# Paciente sub-76J09: Total de pares de recortes (label 1 + label 0): 132
# Paciente sub-79H07: Total de pares de recortes (label 1 + label 0): 436
# Paciente sub-83K08: Total de pares de recortes (label 1 + label 0): 52
# Paciente sub-85I05: Total de pares de recortes (label 1 + label 0): 330
# Paciente sub-86G08: Total de pares de recortes (label 1 + label 0): 100
# Paciente sub-87G01: Total de pares de recortes (label 1 + label 0): 164
# Paciente sub-89A03: Total de pares de recortes (label 1 + label 0): 128
# Paciente sub-90K10: Total de pares de recortes (label 1 + label 0): 288
# Total de pares de recortes no treino (1*['sub-79H07', 'sub-71C07', 'sub-06C09', 'sub-90K10', 'sub-83K08', 'sub-19F09', 'sub-59G00', 'sub-16I12', 'sub-00H10', 'sub-35E12', 'sub-03C08', 'sub-36K02', 'sub-56E13', 'sub-52K04', 'sub-59E09', 'sub-72K02', 'sub-87G01', 'sub-85I05', 'sub-26B09', 'sub-54K08', 'sub-72I02', 'sub-02A13', 'sub-51C05', 'sub-41D08', 'sub-16G09', 'sub-31F07', 'sub-29D03', 'sub-60K04']) com label 1: 2537
# Total de pares de recortes no treino (1*['sub-79H07', 'sub-71C07', 'sub-06C09', 'sub-90K10', 'sub-83K08', 'sub-19F09', 'sub-59G00', 'sub-16I12', 'sub-00H10', 'sub-35E12', 'sub-03C08', 'sub-36K02', 'sub-56E13', 'sub-52K04', 'sub-59E09', 'sub-72K02', 'sub-87G01', 'sub-85I05', 'sub-26B09', 'sub-54K08', 'sub-72I02', 'sub-02A13', 'sub-51C05', 'sub-41D08', 'sub-16G09', 'sub-31F07', 'sub-29D03', 'sub-60K04']) com label 0: 2537
# Total de pares de recortes na validação (1*['sub-76E02', 'sub-34J06', 'sub-57D04', 'sub-89A03', 'sub-42B05', 'sub-22F14', 'sub-19G04', 'sub-86G08']) com label 1: 542
# Total de pares de recortes na validação (1*['sub-76E02', 'sub-34J06', 'sub-57D04', 'sub-89A03', 'sub-42B05', 'sub-22F14', 'sub-19G04', 'sub-86G08']) com label 0: 542
# Total de pares de recortes no teste com (1*['sub-76J09', 'sub-16E03', 'sub-25B08', 'sub-60G06', 'sub-44H05']) label 1: 476
# Total de pares de recortes no teste com (1*['sub-76J09', 'sub-16E03', 'sub-25B08', 'sub-60G06', 'sub-44H05']) label 0: 476

# %%
# Construir e compilar o modelo CNN
input_shape_left = (X_train_left[0].shape)
input_shape_right = (X_train_right[0].shape)

siamese_model = build_siamese_model(input_shape_left, input_shape_right)
siamese_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 128)]                0         []
#
#  input_6 (InputLayer)        [(None, 128)]                0         []
#
#  concatenate_1 (Concatenate  (None, 256)                  0         ['input_5[0][0]',
#  )                                                                   'input_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256)                  1024      ['concatenate_1[1][0]']
#  chNormalization)
#
#  dense_5 (Dense)             (None, 1)                    257       ['batch_normalization_1[1][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 1281 (5.00 KB)
# Trainable params: 769 (3.00 KB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________

# %%
# Adicionar o callback EarlyStopping e low rate scheduler
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Treinamento do modelo  
history = siamese_model.fit([X_train_left, X_train_right], y_train, validation_data=([X_valid_left, X_valid_right], y_valid), batch_size=64, epochs=200, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 5
#       2 early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
#       4 # Treinamento do modelo
# ----> 5 history = siamese_model.fit([X_train_left, X_train_right], y_train, validation_data=([X_valid_left, X_valid_right], y_valid), batch_size=64, epochs=200, callbacks=[early_stopping])
#
# File c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File C:\Users\GABRIE~1\AppData\Local\Temp\__autograph_generated_fileh5cs85tn.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 1150, in train_step
#         y_pred = self(x, training=True)
#     File "c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model_1" is incompatible with the layer: expected shape=(None, 128), found shape=(None, 70, 70, 1)

# %%
# Avaliar o modelo
y_pred = (siamese_model.predict([X_test_left, X_test_right]) >=  0.5)

# Gerar o relatório de classificação
print(classification_report(y_test, y_pred))
# Out:
# 33/33 [==============================] - 1s 25ms/step
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67       527
#            1       0.68      0.62      0.65       527
#
#     accuracy                           0.66      1054
#    macro avg       0.66      0.66      0.66      1054
# weighted avg       0.66      0.66      0.66      1054

# %%
# Gerar a matriz de confusão
plot_confusion_matrix(y_test, y_pred)

# %%
# Plotar o histórico do treinamento
plot_training_history(history)

# %%
# Função para plotar e salvar as imagens com legenda no PDF
def plot_images_to_pdf(X_test_left, X_test_right, y_test, pdf_path='Pdf/Pacientes_Conjunto_Teste.pdf'):
    # Abre o arquivo PDF para escrita
    with PdfPages(pdf_path) as pdf:
        for i in range(len(y_test)):
            # Exibe progresso
            print(f"Processando imagem {i + 1} de {len(y_pred)}")

            # Configuração da figura
            fig, axs = plt.subplots(1, 2, figsize=(4, 4))
            fig.suptitle(f'Label Pred.: {"Sim" if y_pred[i] == 1 else "Não"}  -  Label Verd.: {"Sim" if y_test[i] == 1 else "Não"}')

            # Exibe as imagens
            axs[0].imshow(X_test_left[i], cmap='gray')
            axs[0].set_title('MRI Esquerda')
            axs[0].axis('off')

            axs[1].imshow(X_test_right[i], cmap='gray')
            axs[1].set_title('MRI Direita')
            axs[1].axis('off')

            # Adiciona a figura atual ao PDF
            pdf.savefig(fig)
            plt.close(fig)

    print(f"As imagens foram salvas no arquivo PDF '{pdf_path}' com sucesso.")

# Chame a função com seus dados
plot_images_to_pdf(X_test_left, X_test_right, y_test)
# Out:
# Processando imagem 1 de 1054
# Processando imagem 2 de 1054
# Processando imagem 3 de 1054
# Processando imagem 4 de 1054
# Processando imagem 5 de 1054
# Processando imagem 6 de 1054
# Processando imagem 7 de 1054
# Processando imagem 8 de 1054
# Processando imagem 9 de 1054
# Processando imagem 10 de 1054
# Processando imagem 11 de 1054
# Processando imagem 12 de 1054
# Processando imagem 13 de 1054
# Processando imagem 14 de 1054
# Processando imagem 15 de 1054
# Processando imagem 16 de 1054
# Processando imagem 17 de 1054
# Processando imagem 18 de 1054
# Processando imagem 19 de 1054
# Processando imagem 20 de 1054
# Processando imagem 21 de 1054
# Processando imagem 22 de 1054
# Processando imagem 23 de 1054
# Processando imagem 24 de 1054
# Processando imagem 25 de 1054
# Processando imagem 26 de 1054
# Processando imagem 27 de 1054
# Processando imagem 28 de 1054
# Processando imagem 29 de 1054
# Processando imagem 30 de 1054
# Processando imagem 31 de 1054
# Processando imagem 32 de 1054
# Processando imagem 33 de 1054
# Processando imagem 34 de 1054
# Processando imagem 35 de 1054
# Processando imagem 36 de 1054
# Processando imagem 37 de 1054
# Processando imagem 38 de 1054
# Processando imagem 39 de 1054
# Processando imagem 40 de 1054
# Processando imagem 41 de 1054
# Processando imagem 42 de 1054
# Processando imagem 43 de 1054
# Processando imagem 44 de 1054
# Processando imagem 45 de 1054
# Processando imagem 46 de 1054
# Processando imagem 47 de 1054
# Processando imagem 48 de 1054
# Processando imagem 49 de 1054
# Processando imagem 50 de 1054
# Processando imagem 51 de 1054
# Processando imagem 52 de 1054
# Processando imagem 53 de 1054
# Processando imagem 54 de 1054
# Processando imagem 55 de 1054
# Processando imagem 56 de 1054
# Processando imagem 57 de 1054
# Processando imagem 58 de 1054
# Processando imagem 59 de 1054
# Processando imagem 60 de 1054
# Processando imagem 61 de 1054
# Processando imagem 62 de 1054
# Processando imagem 63 de 1054
# Processando imagem 64 de 1054
# Processando imagem 65 de 1054
# Processando imagem 66 de 1054
# Processando imagem 67 de 1054
# Processando imagem 68 de 1054
# Processando imagem 69 de 1054
# Processando imagem 70 de 1054
# Processando imagem 71 de 1054
# Processando imagem 72 de 1054
# Processando imagem 73 de 1054
# Processando imagem 74 de 1054
# Processando imagem 75 de 1054
# Processando imagem 76 de 1054
# Processando imagem 77 de 1054
# Processando imagem 78 de 1054
# Processando imagem 79 de 1054
# Processando imagem 80 de 1054
# Processando imagem 81 de 1054
# Processando imagem 82 de 1054
# Processando imagem 83 de 1054
# Processando imagem 84 de 1054
# Processando imagem 85 de 1054
# Processando imagem 86 de 1054
# Processando imagem 87 de 1054
# Processando imagem 88 de 1054
# Processando imagem 89 de 1054
# Processando imagem 90 de 1054
# Processando imagem 91 de 1054
# Processando imagem 92 de 1054
# Processando imagem 93 de 1054
# Processando imagem 94 de 1054
# Processando imagem 95 de 1054
# Processando imagem 96 de 1054
# Processando imagem 97 de 1054
# Processando imagem 98 de 1054
# Processando imagem 99 de 1054
# Processando imagem 100 de 1054
# Processando imagem 101 de 1054
# Processando imagem 102 de 1054
# Processando imagem 103 de 1054
# Processando imagem 104 de 1054
# Processando imagem 105 de 1054
# Processando imagem 106 de 1054
# Processando imagem 107 de 1054
# Processando imagem 108 de 1054
# Processando imagem 109 de 1054
# Processando imagem 110 de 1054
# Processando imagem 111 de 1054
# Processando imagem 112 de 1054
# Processando imagem 113 de 1054
# Processando imagem 114 de 1054
# Processando imagem 115 de 1054
# Processando imagem 116 de 1054
# Processando imagem 117 de 1054
# Processando imagem 118 de 1054
# Processando imagem 119 de 1054
# Processando imagem 120 de 1054
# Processando imagem 121 de 1054
# Processando imagem 122 de 1054
# Processando imagem 123 de 1054
# Processando imagem 124 de 1054
# Processando imagem 125 de 1054
# Processando imagem 126 de 1054
# Processando imagem 127 de 1054
# Processando imagem 128 de 1054
# Processando imagem 129 de 1054
# Processando imagem 130 de 1054
# Processando imagem 131 de 1054
# Processando imagem 132 de 1054
# Processando imagem 133 de 1054
# Processando imagem 134 de 1054
# Processando imagem 135 de 1054
# Processando imagem 136 de 1054
# Processando imagem 137 de 1054
# Processando imagem 138 de 1054
# Processando imagem 139 de 1054
# Processando imagem 140 de 1054
# Processando imagem 141 de 1054
# Processando imagem 142 de 1054
# Processando imagem 143 de 1054
# Processando imagem 144 de 1054
# Processando imagem 145 de 1054
# Processando imagem 146 de 1054
# Processando imagem 147 de 1054
# Processando imagem 148 de 1054
# Processando imagem 149 de 1054
# Processando imagem 150 de 1054
# Processando imagem 151 de 1054
# Processando imagem 152 de 1054
# Processando imagem 153 de 1054
# Processando imagem 154 de 1054
# Processando imagem 155 de 1054
# Processando imagem 156 de 1054
# Processando imagem 157 de 1054
# Processando imagem 158 de 1054
# Processando imagem 159 de 1054
# Processando imagem 160 de 1054
# Processando imagem 161 de 1054
# Processando imagem 162 de 1054
# Processando imagem 163 de 1054
# Processando imagem 164 de 1054
# Processando imagem 165 de 1054
# Processando imagem 166 de 1054
# Processando imagem 167 de 1054
# Processando imagem 168 de 1054
# Processando imagem 169 de 1054
# Processando imagem 170 de 1054
# Processando imagem 171 de 1054
# Processando imagem 172 de 1054
# Processando imagem 173 de 1054
# Processando imagem 174 de 1054
# Processando imagem 175 de 1054
# Processando imagem 176 de 1054
# Processando imagem 177 de 1054
# Processando imagem 178 de 1054
# Processando imagem 179 de 1054
# Processando imagem 180 de 1054
# Processando imagem 181 de 1054
# Processando imagem 182 de 1054
# Processando imagem 183 de 1054
# Processando imagem 184 de 1054
# Processando imagem 185 de 1054
# Processando imagem 186 de 1054
# Processando imagem 187 de 1054
# Processando imagem 188 de 1054
# Processando imagem 189 de 1054
# Processando imagem 190 de 1054
# Processando imagem 191 de 1054
# Processando imagem 192 de 1054
# Processando imagem 193 de 1054
# Processando imagem 194 de 1054
# Processando imagem 195 de 1054
# Processando imagem 196 de 1054
# Processando imagem 197 de 1054
# Processando imagem 198 de 1054
# Processando imagem 199 de 1054
# Processando imagem 200 de 1054
# Processando imagem 201 de 1054
# Processando imagem 202 de 1054
# Processando imagem 203 de 1054
# Processando imagem 204 de 1054
# Processando imagem 205 de 1054
# Processando imagem 206 de 1054
# Processando imagem 207 de 1054
# Processando imagem 208 de 1054
# Processando imagem 209 de 1054
# Processando imagem 210 de 1054
# Processando imagem 211 de 1054
# Processando imagem 212 de 1054
# Processando imagem 213 de 1054
# Processando imagem 214 de 1054
# Processando imagem 215 de 1054
# Processando imagem 216 de 1054
# Processando imagem 217 de 1054
# Processando imagem 218 de 1054
# Processando imagem 219 de 1054
# Processando imagem 220 de 1054
# Processando imagem 221 de 1054
# Processando imagem 222 de 1054
# Processando imagem 223 de 1054
# Processando imagem 224 de 1054
# Processando imagem 225 de 1054
# Processando imagem 226 de 1054
# Processando imagem 227 de 1054
# Processando imagem 228 de 1054
# Processando imagem 229 de 1054
# Processando imagem 230 de 1054
# Processando imagem 231 de 1054
# Processando imagem 232 de 1054
# Processando imagem 233 de 1054
# Processando imagem 234 de 1054
# Processando imagem 235 de 1054
# Processando imagem 236 de 1054
# Processando imagem 237 de 1054
# Processando imagem 238 de 1054
# Processando imagem 239 de 1054
# Processando imagem 240 de 1054
# Processando imagem 241 de 1054
# Processando imagem 242 de 1054
# Processando imagem 243 de 1054
# Processando imagem 244 de 1054
# Processando imagem 245 de 1054
# Processando imagem 246 de 1054
# Processando imagem 247 de 1054
# Processando imagem 248 de 1054
# Processando imagem 249 de 1054
# Processando imagem 250 de 1054
# Processando imagem 251 de 1054
# Processando imagem 252 de 1054
# Processando imagem 253 de 1054
# Processando imagem 254 de 1054
# Processando imagem 255 de 1054
# Processando imagem 256 de 1054
# Processando imagem 257 de 1054
# Processando imagem 258 de 1054
# Processando imagem 259 de 1054
# Processando imagem 260 de 1054
# Processando imagem 261 de 1054
# Processando imagem 262 de 1054
# Processando imagem 263 de 1054
# Processando imagem 264 de 1054
# Processando imagem 265 de 1054
# Processando imagem 266 de 1054
# Processando imagem 267 de 1054
# Processando imagem 268 de 1054
# Processando imagem 269 de 1054
# Processando imagem 270 de 1054
# Processando imagem 271 de 1054
# Processando imagem 272 de 1054
# Processando imagem 273 de 1054
# Processando imagem 274 de 1054
# Processando imagem 275 de 1054
# Processando imagem 276 de 1054
# Processando imagem 277 de 1054
# Processando imagem 278 de 1054
# Processando imagem 279 de 1054
# Processando imagem 280 de 1054
# Processando imagem 281 de 1054
# Processando imagem 282 de 1054
# Processando imagem 283 de 1054
# Processando imagem 284 de 1054
# Processando imagem 285 de 1054
# Processando imagem 286 de 1054
# Processando imagem 287 de 1054
# Processando imagem 288 de 1054
# Processando imagem 289 de 1054
# Processando imagem 290 de 1054
# Processando imagem 291 de 1054
# Processando imagem 292 de 1054
# Processando imagem 293 de 1054
# Processando imagem 294 de 1054
# Processando imagem 295 de 1054
# Processando imagem 296 de 1054
# Processando imagem 297 de 1054
# Processando imagem 298 de 1054
# Processando imagem 299 de 1054
# Processando imagem 300 de 1054
# Processando imagem 301 de 1054
# Processando imagem 302 de 1054
# Processando imagem 303 de 1054
# Processando imagem 304 de 1054
# Processando imagem 305 de 1054
# Processando imagem 306 de 1054
# Processando imagem 307 de 1054
# Processando imagem 308 de 1054
# Processando imagem 309 de 1054
# Processando imagem 310 de 1054
# Processando imagem 311 de 1054
# Processando imagem 312 de 1054
# Processando imagem 313 de 1054
# Processando imagem 314 de 1054
# Processando imagem 315 de 1054
# Processando imagem 316 de 1054
# Processando imagem 317 de 1054
# Processando imagem 318 de 1054
# Processando imagem 319 de 1054
# Processando imagem 320 de 1054
# Processando imagem 321 de 1054
# Processando imagem 322 de 1054
# Processando imagem 323 de 1054
# Processando imagem 324 de 1054
# Processando imagem 325 de 1054
# Processando imagem 326 de 1054
# Processando imagem 327 de 1054
# Processando imagem 328 de 1054
# Processando imagem 329 de 1054
# Processando imagem 330 de 1054
# Processando imagem 331 de 1054
# Processando imagem 332 de 1054
# Processando imagem 333 de 1054
# Processando imagem 334 de 1054
# Processando imagem 335 de 1054
# Processando imagem 336 de 1054
# Processando imagem 337 de 1054
# Processando imagem 338 de 1054
# Processando imagem 339 de 1054
# Processando imagem 340 de 1054
# Processando imagem 341 de 1054
# Processando imagem 342 de 1054
# Processando imagem 343 de 1054
# Processando imagem 344 de 1054
# Processando imagem 345 de 1054
# Processando imagem 346 de 1054
# Processando imagem 347 de 1054
# Processando imagem 348 de 1054
# Processando imagem 349 de 1054
# Processando imagem 350 de 1054
# Processando imagem 351 de 1054
# Processando imagem 352 de 1054
# Processando imagem 353 de 1054
# Processando imagem 354 de 1054
# Processando imagem 355 de 1054
# Processando imagem 356 de 1054
# Processando imagem 357 de 1054
# Processando imagem 358 de 1054
# Processando imagem 359 de 1054
# Processando imagem 360 de 1054
# Processando imagem 361 de 1054
# Processando imagem 362 de 1054
# Processando imagem 363 de 1054
# Processando imagem 364 de 1054
# Processando imagem 365 de 1054
# Processando imagem 366 de 1054
# Processando imagem 367 de 1054
# Processando imagem 368 de 1054
# Processando imagem 369 de 1054
# Processando imagem 370 de 1054
# Processando imagem 371 de 1054
# Processando imagem 372 de 1054
# Processando imagem 373 de 1054
# Processando imagem 374 de 1054
# Processando imagem 375 de 1054
# Processando imagem 376 de 1054
# Processando imagem 377 de 1054
# Processando imagem 378 de 1054
# Processando imagem 379 de 1054
# Processando imagem 380 de 1054
# Processando imagem 381 de 1054
# Processando imagem 382 de 1054
# Processando imagem 383 de 1054
# Processando imagem 384 de 1054
# Processando imagem 385 de 1054
# Processando imagem 386 de 1054
# Processando imagem 387 de 1054
# Processando imagem 388 de 1054
# Processando imagem 389 de 1054
# Processando imagem 390 de 1054
# Processando imagem 391 de 1054
# Processando imagem 392 de 1054
# Processando imagem 393 de 1054
# Processando imagem 394 de 1054
# Processando imagem 395 de 1054
# Processando imagem 396 de 1054
# Processando imagem 397 de 1054
# Processando imagem 398 de 1054
# Processando imagem 399 de 1054
# Processando imagem 400 de 1054
# Processando imagem 401 de 1054
# Processando imagem 402 de 1054
# Processando imagem 403 de 1054
# Processando imagem 404 de 1054
# Processando imagem 405 de 1054
# Processando imagem 406 de 1054
# Processando imagem 407 de 1054
# Processando imagem 408 de 1054
# Processando imagem 409 de 1054
# Processando imagem 410 de 1054
# Processando imagem 411 de 1054
# Processando imagem 412 de 1054
# Processando imagem 413 de 1054
# Processando imagem 414 de 1054
# Processando imagem 415 de 1054
# Processando imagem 416 de 1054
# Processando imagem 417 de 1054
# Processando imagem 418 de 1054
# Processando imagem 419 de 1054
# Processando imagem 420 de 1054
# Processando imagem 421 de 1054
# Processando imagem 422 de 1054
# Processando imagem 423 de 1054
# Processando imagem 424 de 1054
# Processando imagem 425 de 1054
# Processando imagem 426 de 1054
# Processando imagem 427 de 1054
# Processando imagem 428 de 1054
# Processando imagem 429 de 1054
# Processando imagem 430 de 1054
# Processando imagem 431 de 1054
# Processando imagem 432 de 1054
# Processando imagem 433 de 1054
# Processando imagem 434 de 1054
# Processando imagem 435 de 1054
# Processando imagem 436 de 1054
# Processando imagem 437 de 1054
# Processando imagem 438 de 1054
# Processando imagem 439 de 1054
# Processando imagem 440 de 1054
# Processando imagem 441 de 1054
# Processando imagem 442 de 1054
# Processando imagem 443 de 1054
# Processando imagem 444 de 1054
# Processando imagem 445 de 1054
# Processando imagem 446 de 1054
# Processando imagem 447 de 1054
# Processando imagem 448 de 1054
# Processando imagem 449 de 1054
# Processando imagem 450 de 1054
# Processando imagem 451 de 1054
# Processando imagem 452 de 1054
# Processando imagem 453 de 1054
# Processando imagem 454 de 1054
# Processando imagem 455 de 1054
# Processando imagem 456 de 1054
# Processando imagem 457 de 1054
# Processando imagem 458 de 1054
# Processando imagem 459 de 1054
# Processando imagem 460 de 1054
# Processando imagem 461 de 1054
# Processando imagem 462 de 1054
# Processando imagem 463 de 1054
# Processando imagem 464 de 1054
# Processando imagem 465 de 1054
# Processando imagem 466 de 1054
# Processando imagem 467 de 1054
# Processando imagem 468 de 1054
# Processando imagem 469 de 1054
# Processando imagem 470 de 1054
# Processando imagem 471 de 1054
# Processando imagem 472 de 1054
# Processando imagem 473 de 1054
# Processando imagem 474 de 1054
# Processando imagem 475 de 1054
# Processando imagem 476 de 1054
# Processando imagem 477 de 1054
# Processando imagem 478 de 1054
# Processando imagem 479 de 1054
# Processando imagem 480 de 1054
# Processando imagem 481 de 1054
# Processando imagem 482 de 1054
# Processando imagem 483 de 1054
# Processando imagem 484 de 1054
# Processando imagem 485 de 1054
# Processando imagem 486 de 1054
# Processando imagem 487 de 1054
# Processando imagem 488 de 1054
# Processando imagem 489 de 1054
# Processando imagem 490 de 1054
# Processando imagem 491 de 1054
# Processando imagem 492 de 1054
# Processando imagem 493 de 1054
# Processando imagem 494 de 1054
# Processando imagem 495 de 1054
# Processando imagem 496 de 1054
# Processando imagem 497 de 1054
# Processando imagem 498 de 1054
# Processando imagem 499 de 1054
# Processando imagem 500 de 1054
# Processando imagem 501 de 1054
# Processando imagem 502 de 1054
# Processando imagem 503 de 1054
# Processando imagem 504 de 1054
# Processando imagem 505 de 1054
# Processando imagem 506 de 1054
# Processando imagem 507 de 1054
# Processando imagem 508 de 1054
# Processando imagem 509 de 1054
# Processando imagem 510 de 1054
# Processando imagem 511 de 1054
# Processando imagem 512 de 1054
# Processando imagem 513 de 1054
# Processando imagem 514 de 1054
# Processando imagem 515 de 1054
# Processando imagem 516 de 1054
# Processando imagem 517 de 1054
# Processando imagem 518 de 1054
# Processando imagem 519 de 1054
# Processando imagem 520 de 1054
# Processando imagem 521 de 1054
# Processando imagem 522 de 1054
# Processando imagem 523 de 1054
# Processando imagem 524 de 1054
# Processando imagem 525 de 1054
# Processando imagem 526 de 1054
# Processando imagem 527 de 1054
# Processando imagem 528 de 1054
# Processando imagem 529 de 1054
# Processando imagem 530 de 1054
# Processando imagem 531 de 1054
# Processando imagem 532 de 1054
# Processando imagem 533 de 1054
# Processando imagem 534 de 1054
# Processando imagem 535 de 1054
# Processando imagem 536 de 1054
# Processando imagem 537 de 1054
# Processando imagem 538 de 1054
# Processando imagem 539 de 1054
# Processando imagem 540 de 1054
# Processando imagem 541 de 1054
# Processando imagem 542 de 1054
# Processando imagem 543 de 1054
# Processando imagem 544 de 1054
# Processando imagem 545 de 1054
# Processando imagem 546 de 1054
# Processando imagem 547 de 1054
# Processando imagem 548 de 1054
# Processando imagem 549 de 1054
# Processando imagem 550 de 1054
# Processando imagem 551 de 1054
# Processando imagem 552 de 1054
# Processando imagem 553 de 1054
# Processando imagem 554 de 1054
# Processando imagem 555 de 1054
# Processando imagem 556 de 1054
# Processando imagem 557 de 1054
# Processando imagem 558 de 1054
# Processando imagem 559 de 1054
# Processando imagem 560 de 1054
# Processando imagem 561 de 1054
# Processando imagem 562 de 1054
# Processando imagem 563 de 1054
# Processando imagem 564 de 1054
# Processando imagem 565 de 1054
# Processando imagem 566 de 1054
# Processando imagem 567 de 1054
# Processando imagem 568 de 1054
# Processando imagem 569 de 1054
# Processando imagem 570 de 1054
# Processando imagem 571 de 1054
# Processando imagem 572 de 1054
# Processando imagem 573 de 1054
# Processando imagem 574 de 1054
# Processando imagem 575 de 1054
# Processando imagem 576 de 1054
# Processando imagem 577 de 1054
# Processando imagem 578 de 1054
# Processando imagem 579 de 1054
# Processando imagem 580 de 1054
# Processando imagem 581 de 1054
# Processando imagem 582 de 1054
# Processando imagem 583 de 1054
# Processando imagem 584 de 1054
# Processando imagem 585 de 1054
# Processando imagem 586 de 1054
# Processando imagem 587 de 1054
# Processando imagem 588 de 1054
# Processando imagem 589 de 1054
# Processando imagem 590 de 1054
# Processando imagem 591 de 1054
# Processando imagem 592 de 1054
# Processando imagem 593 de 1054
# Processando imagem 594 de 1054
# Processando imagem 595 de 1054
# Processando imagem 596 de 1054
# Processando imagem 597 de 1054
# Processando imagem 598 de 1054
# Processando imagem 599 de 1054
# Processando imagem 600 de 1054
# Processando imagem 601 de 1054
# Processando imagem 602 de 1054
# Processando imagem 603 de 1054
# Processando imagem 604 de 1054
# Processando imagem 605 de 1054
# Processando imagem 606 de 1054
# Processando imagem 607 de 1054
# Processando imagem 608 de 1054
# Processando imagem 609 de 1054
# Processando imagem 610 de 1054
# Processando imagem 611 de 1054
# Processando imagem 612 de 1054
# Processando imagem 613 de 1054
# Processando imagem 614 de 1054
# Processando imagem 615 de 1054
# Processando imagem 616 de 1054
# Processando imagem 617 de 1054
# Processando imagem 618 de 1054
# Processando imagem 619 de 1054
# Processando imagem 620 de 1054
# Processando imagem 621 de 1054
# Processando imagem 622 de 1054
# Processando imagem 623 de 1054
# Processando imagem 624 de 1054
# Processando imagem 625 de 1054
# Processando imagem 626 de 1054
# Processando imagem 627 de 1054
# Processando imagem 628 de 1054
# Processando imagem 629 de 1054
# Processando imagem 630 de 1054
# Processando imagem 631 de 1054
# Processando imagem 632 de 1054
# Processando imagem 633 de 1054
# Processando imagem 634 de 1054
# Processando imagem 635 de 1054
# Processando imagem 636 de 1054
# Processando imagem 637 de 1054
# Processando imagem 638 de 1054
# Processando imagem 639 de 1054
# Processando imagem 640 de 1054
# Processando imagem 641 de 1054
# Processando imagem 642 de 1054
# Processando imagem 643 de 1054
# Processando imagem 644 de 1054
# Processando imagem 645 de 1054
# Processando imagem 646 de 1054
# Processando imagem 647 de 1054
# Processando imagem 648 de 1054
# Processando imagem 649 de 1054
# Processando imagem 650 de 1054
# Processando imagem 651 de 1054
# Processando imagem 652 de 1054
# Processando imagem 653 de 1054
# Processando imagem 654 de 1054
# Processando imagem 655 de 1054
# Processando imagem 656 de 1054
# Processando imagem 657 de 1054
# Processando imagem 658 de 1054
# Processando imagem 659 de 1054
# Processando imagem 660 de 1054
# Processando imagem 661 de 1054
# Processando imagem 662 de 1054
# Processando imagem 663 de 1054
# Processando imagem 664 de 1054
# Processando imagem 665 de 1054
# Processando imagem 666 de 1054
# Processando imagem 667 de 1054
# Processando imagem 668 de 1054
# Processando imagem 669 de 1054
# Processando imagem 670 de 1054
# Processando imagem 671 de 1054
# Processando imagem 672 de 1054
# Processando imagem 673 de 1054
# Processando imagem 674 de 1054
# Processando imagem 675 de 1054
# Processando imagem 676 de 1054
# Processando imagem 677 de 1054
# Processando imagem 678 de 1054
# Processando imagem 679 de 1054
# Processando imagem 680 de 1054
# Processando imagem 681 de 1054
# Processando imagem 682 de 1054
# Processando imagem 683 de 1054
# Processando imagem 684 de 1054
# Processando imagem 685 de 1054
# Processando imagem 686 de 1054
# Processando imagem 687 de 1054
# Processando imagem 688 de 1054
# Processando imagem 689 de 1054
# Processando imagem 690 de 1054
# Processando imagem 691 de 1054
# Processando imagem 692 de 1054
# Processando imagem 693 de 1054
# Processando imagem 694 de 1054
# Processando imagem 695 de 1054
# Processando imagem 696 de 1054
# Processando imagem 697 de 1054
# Processando imagem 698 de 1054
# Processando imagem 699 de 1054
# Processando imagem 700 de 1054
# Processando imagem 701 de 1054
# Processando imagem 702 de 1054
# Processando imagem 703 de 1054
# Processando imagem 704 de 1054
# Processando imagem 705 de 1054
# Processando imagem 706 de 1054
# Processando imagem 707 de 1054
# Processando imagem 708 de 1054
# Processando imagem 709 de 1054
# Processando imagem 710 de 1054
# Processando imagem 711 de 1054
# Processando imagem 712 de 1054
# Processando imagem 713 de 1054
# Processando imagem 714 de 1054
# Processando imagem 715 de 1054
# Processando imagem 716 de 1054
# Processando imagem 717 de 1054
# Processando imagem 718 de 1054
# Processando imagem 719 de 1054
# Processando imagem 720 de 1054
# Processando imagem 721 de 1054
# Processando imagem 722 de 1054
# Processando imagem 723 de 1054
# Processando imagem 724 de 1054
# Processando imagem 725 de 1054
# Processando imagem 726 de 1054
# Processando imagem 727 de 1054
# Processando imagem 728 de 1054
# Processando imagem 729 de 1054
# Processando imagem 730 de 1054
# Processando imagem 731 de 1054
# Processando imagem 732 de 1054
# Processando imagem 733 de 1054
# Processando imagem 734 de 1054
# Processando imagem 735 de 1054
# Processando imagem 736 de 1054
# Processando imagem 737 de 1054
# Processando imagem 738 de 1054
# Processando imagem 739 de 1054
# Processando imagem 740 de 1054
# Processando imagem 741 de 1054
# Processando imagem 742 de 1054
# Processando imagem 743 de 1054
# Processando imagem 744 de 1054
# Processando imagem 745 de 1054
# Processando imagem 746 de 1054
# Processando imagem 747 de 1054
# Processando imagem 748 de 1054
# Processando imagem 749 de 1054
# Processando imagem 750 de 1054
# Processando imagem 751 de 1054
# Processando imagem 752 de 1054
# Processando imagem 753 de 1054
# Processando imagem 754 de 1054
# Processando imagem 755 de 1054
# Processando imagem 756 de 1054
# Processando imagem 757 de 1054
# Processando imagem 758 de 1054
# Processando imagem 759 de 1054
# Processando imagem 760 de 1054
# Processando imagem 761 de 1054
# Processando imagem 762 de 1054
# Processando imagem 763 de 1054
# Processando imagem 764 de 1054
# Processando imagem 765 de 1054
# Processando imagem 766 de 1054
# Processando imagem 767 de 1054
# Processando imagem 768 de 1054
# Processando imagem 769 de 1054
# Processando imagem 770 de 1054
# Processando imagem 771 de 1054
# Processando imagem 772 de 1054
# Processando imagem 773 de 1054
# Processando imagem 774 de 1054
# Processando imagem 775 de 1054
# Processando imagem 776 de 1054
# Processando imagem 777 de 1054
# Processando imagem 778 de 1054
# Processando imagem 779 de 1054
# Processando imagem 780 de 1054
# Processando imagem 781 de 1054
# Processando imagem 782 de 1054
# Processando imagem 783 de 1054
# Processando imagem 784 de 1054
# Processando imagem 785 de 1054
# Processando imagem 786 de 1054
# Processando imagem 787 de 1054
# Processando imagem 788 de 1054
# Processando imagem 789 de 1054
# Processando imagem 790 de 1054
# Processando imagem 791 de 1054
# Processando imagem 792 de 1054
# Processando imagem 793 de 1054
# Processando imagem 794 de 1054
# Processando imagem 795 de 1054
# Processando imagem 796 de 1054
# Processando imagem 797 de 1054
# Processando imagem 798 de 1054
# Processando imagem 799 de 1054
# Processando imagem 800 de 1054
# Processando imagem 801 de 1054
# Processando imagem 802 de 1054
# Processando imagem 803 de 1054
# Processando imagem 804 de 1054
# Processando imagem 805 de 1054
# Processando imagem 806 de 1054
# Processando imagem 807 de 1054
# Processando imagem 808 de 1054
# Processando imagem 809 de 1054
# Processando imagem 810 de 1054
# Processando imagem 811 de 1054
# Processando imagem 812 de 1054
# Processando imagem 813 de 1054
# Processando imagem 814 de 1054
# Processando imagem 815 de 1054
# Processando imagem 816 de 1054
# Processando imagem 817 de 1054
# Processando imagem 818 de 1054
# Processando imagem 819 de 1054
# Processando imagem 820 de 1054
# Processando imagem 821 de 1054
# Processando imagem 822 de 1054
# Processando imagem 823 de 1054
# Processando imagem 824 de 1054
# Processando imagem 825 de 1054
# Processando imagem 826 de 1054
# Processando imagem 827 de 1054
# Processando imagem 828 de 1054
# Processando imagem 829 de 1054
# Processando imagem 830 de 1054
# Processando imagem 831 de 1054
# Processando imagem 832 de 1054
# Processando imagem 833 de 1054
# Processando imagem 834 de 1054
# Processando imagem 835 de 1054
# Processando imagem 836 de 1054
# Processando imagem 837 de 1054
# Processando imagem 838 de 1054
# Processando imagem 839 de 1054
# Processando imagem 840 de 1054
# Processando imagem 841 de 1054
# Processando imagem 842 de 1054
# Processando imagem 843 de 1054
# Processando imagem 844 de 1054
# Processando imagem 845 de 1054
# Processando imagem 846 de 1054
# Processando imagem 847 de 1054
# Processando imagem 848 de 1054
# Processando imagem 849 de 1054
# Processando imagem 850 de 1054
# Processando imagem 851 de 1054
# Processando imagem 852 de 1054
# Processando imagem 853 de 1054
# Processando imagem 854 de 1054
# Processando imagem 855 de 1054
# Processando imagem 856 de 1054
# Processando imagem 857 de 1054
# Processando imagem 858 de 1054
# Processando imagem 859 de 1054
# Processando imagem 860 de 1054
# Processando imagem 861 de 1054
# Processando imagem 862 de 1054
# Processando imagem 863 de 1054
# Processando imagem 864 de 1054
# Processando imagem 865 de 1054
# Processando imagem 866 de 1054
# Processando imagem 867 de 1054
# Processando imagem 868 de 1054
# Processando imagem 869 de 1054
# Processando imagem 870 de 1054
# Processando imagem 871 de 1054
# Processando imagem 872 de 1054
# Processando imagem 873 de 1054
# Processando imagem 874 de 1054
# Processando imagem 875 de 1054
# Processando imagem 876 de 1054
# Processando imagem 877 de 1054
# Processando imagem 878 de 1054
# Processando imagem 879 de 1054
# Processando imagem 880 de 1054
# Processando imagem 881 de 1054
# Processando imagem 882 de 1054
# Processando imagem 883 de 1054
# Processando imagem 884 de 1054
# Processando imagem 885 de 1054
# Processando imagem 886 de 1054
# Processando imagem 887 de 1054
# Processando imagem 888 de 1054
# Processando imagem 889 de 1054
# Processando imagem 890 de 1054
# Processando imagem 891 de 1054
# Processando imagem 892 de 1054
# Processando imagem 893 de 1054
# Processando imagem 894 de 1054
# Processando imagem 895 de 1054
# Processando imagem 896 de 1054
# Processando imagem 897 de 1054
# Processando imagem 898 de 1054
# Processando imagem 899 de 1054
# Processando imagem 900 de 1054
# Processando imagem 901 de 1054
# Processando imagem 902 de 1054
# Processando imagem 903 de 1054
# Processando imagem 904 de 1054
# Processando imagem 905 de 1054
# Processando imagem 906 de 1054
# Processando imagem 907 de 1054
# Processando imagem 908 de 1054
# Processando imagem 909 de 1054
# Processando imagem 910 de 1054
# Processando imagem 911 de 1054
# Processando imagem 912 de 1054
# Processando imagem 913 de 1054
# Processando imagem 914 de 1054
# Processando imagem 915 de 1054
# Processando imagem 916 de 1054
# Processando imagem 917 de 1054
# Processando imagem 918 de 1054
# Processando imagem 919 de 1054
# Processando imagem 920 de 1054
# Processando imagem 921 de 1054
# Processando imagem 922 de 1054
# Processando imagem 923 de 1054
# Processando imagem 924 de 1054
# Processando imagem 925 de 1054
# Processando imagem 926 de 1054
# Processando imagem 927 de 1054
# Processando imagem 928 de 1054
# Processando imagem 929 de 1054
# Processando imagem 930 de 1054
# Processando imagem 931 de 1054
# Processando imagem 932 de 1054
# Processando imagem 933 de 1054
# Processando imagem 934 de 1054
# Processando imagem 935 de 1054
# Processando imagem 936 de 1054
# Processando imagem 937 de 1054
# Processando imagem 938 de 1054
# Processando imagem 939 de 1054
# Processando imagem 940 de 1054
# Processando imagem 941 de 1054
# Processando imagem 942 de 1054
# Processando imagem 943 de 1054
# Processando imagem 944 de 1054
# Processando imagem 945 de 1054
# Processando imagem 946 de 1054
# Processando imagem 947 de 1054
# Processando imagem 948 de 1054
# Processando imagem 949 de 1054
# Processando imagem 950 de 1054
# Processando imagem 951 de 1054
# Processando imagem 952 de 1054
# Processando imagem 953 de 1054
# Processando imagem 954 de 1054
# Processando imagem 955 de 1054
# Processando imagem 956 de 1054
# Processando imagem 957 de 1054
# Processando imagem 958 de 1054
# Processando imagem 959 de 1054
# Processando imagem 960 de 1054
# Processando imagem 961 de 1054
# Processando imagem 962 de 1054
# Processando imagem 963 de 1054
# Processando imagem 964 de 1054
# Processando imagem 965 de 1054
# Processando imagem 966 de 1054
# Processando imagem 967 de 1054
# Processando imagem 968 de 1054
# Processando imagem 969 de 1054
# Processando imagem 970 de 1054
# Processando imagem 971 de 1054
# Processando imagem 972 de 1054
# Processando imagem 973 de 1054
# Processando imagem 974 de 1054
# Processando imagem 975 de 1054
# Processando imagem 976 de 1054
# Processando imagem 977 de 1054
# Processando imagem 978 de 1054
# Processando imagem 979 de 1054
# Processando imagem 980 de 1054
# Processando imagem 981 de 1054
# Processando imagem 982 de 1054
# Processando imagem 983 de 1054
# Processando imagem 984 de 1054
# Processando imagem 985 de 1054
# Processando imagem 986 de 1054
# Processando imagem 987 de 1054
# Processando imagem 988 de 1054
# Processando imagem 989 de 1054
# Processando imagem 990 de 1054
# Processando imagem 991 de 1054
# Processando imagem 992 de 1054
# Processando imagem 993 de 1054
# Processando imagem 994 de 1054
# Processando imagem 995 de 1054
# Processando imagem 996 de 1054
# Processando imagem 997 de 1054
# Processando imagem 998 de 1054
# Processando imagem 999 de 1054
# Processando imagem 1000 de 1054
# Processando imagem 1001 de 1054
# Processando imagem 1002 de 1054
# Processando imagem 1003 de 1054
# Processando imagem 1004 de 1054
# Processando imagem 1005 de 1054
# Processando imagem 1006 de 1054
# Processando imagem 1007 de 1054
# Processando imagem 1008 de 1054
# Processando imagem 1009 de 1054
# Processando imagem 1010 de 1054
# Processando imagem 1011 de 1054
# Processando imagem 1012 de 1054
# Processando imagem 1013 de 1054
# Processando imagem 1014 de 1054
# Processando imagem 1015 de 1054
# Processando imagem 1016 de 1054
# Processando imagem 1017 de 1054
# Processando imagem 1018 de 1054
# Processando imagem 1019 de 1054
# Processando imagem 1020 de 1054
# Processando imagem 1021 de 1054
# Processando imagem 1022 de 1054
# Processando imagem 1023 de 1054
# Processando imagem 1024 de 1054
# Processando imagem 1025 de 1054
# Processando imagem 1026 de 1054
# Processando imagem 1027 de 1054
# Processando imagem 1028 de 1054
# Processando imagem 1029 de 1054
# Processando imagem 1030 de 1054
# Processando imagem 1031 de 1054
# Processando imagem 1032 de 1054
# Processando imagem 1033 de 1054
# Processando imagem 1034 de 1054
# Processando imagem 1035 de 1054
# Processando imagem 1036 de 1054
# Processando imagem 1037 de 1054
# Processando imagem 1038 de 1054
# Processando imagem 1039 de 1054
# Processando imagem 1040 de 1054
# Processando imagem 1041 de 1054
# Processando imagem 1042 de 1054
# Processando imagem 1043 de 1054
# Processando imagem 1044 de 1054
# Processando imagem 1045 de 1054
# Processando imagem 1046 de 1054
# Processando imagem 1047 de 1054
# Processando imagem 1048 de 1054
# Processando imagem 1049 de 1054
# Processando imagem 1050 de 1054
# Processando imagem 1051 de 1054
# Processando imagem 1052 de 1054
# Processando imagem 1053 de 1054
# Processando imagem 1054 de 1054
# As imagens foram salvas no arquivo PDF 'Pdf/Pacientes_Conjunto_Teste.pdf' com sucesso.
