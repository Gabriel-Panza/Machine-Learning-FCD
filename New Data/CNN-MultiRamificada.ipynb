# %%
import nibabel as nib
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from tqdm import tqdm
from tensorflow.keras import layers, models, callbacks, metrics, Input, Model, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, auc, precision_recall_curve
from sklearn.model_selection import train_test_split
import nrrd
# Out:
# WARNING:tensorflow:From c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def calculate_label(image, threshold=0.01):
    """
    Determina o label da subimagem com base no percentual de fundo não-preto.
    :param subimage: Array da subimagem.
    :param threshold: Percentual mínimo de fundo não-preto para considerar como label 1.
    :return: String indicando o label.
    """
    # Total de pixels na subimagem
    total_pixels = image.size
    # Número de pixels não-preto
    non_zero_pixels = np.count_nonzero(image)
    # Proporção de pixels não-preto
    non_black_ratio = non_zero_pixels / total_pixels if total_pixels > 0 else 0
    
    # Verifica se há lesão e se o fundo não-preto é maior que o limiar
    if np.any(image == 1) and non_black_ratio >= threshold:
        return 1
    else:
        return 0

# Função que carrega os dados com pares de imagens
def load_data_with_pairs(folder):
    if not os.path.exists(folder):
        print(f"A pasta {folder} não existe.")
        return {}, {}, {}, {}, {}
    
    images_left = {}
    images_right = {}
    mask_left = {}
    mask_right = {}
    labels_left = {}
    labels_right = {}
    patient_ids = []

    # Itera sobre os pacientes no diretório
    for patient_id in tqdm(os.listdir(folder), desc="Carregamento de arquivos NIfTI..."):
        patient_path = os.path.join(folder, patient_id)

        areas_image = ["left", "right"]
        areas_mask = ["lesion_left", "lesion_right"]
        path_left = os.path.join(patient_path, areas_image[0])
        path_right = os.path.join(patient_path, areas_image[1])
        lesion_path_left = os.path.join(patient_path, areas_mask[0])
        lesion_path_right = os.path.join(patient_path, areas_mask[1])

        if patient_id not in images_left:
            images_left[patient_id] = []
        if patient_id not in images_right:
            images_right[patient_id] = []
        if patient_id not in mask_left:
            mask_left[patient_id] = []
        if patient_id not in mask_right:
            mask_right[patient_id] = []
        if patient_id not in labels_left:
            labels_left[patient_id] = []
        if patient_id not in labels_right:
            labels_right[patient_id] = []
                    
        # Carrega as imagens e máscaras do lado esquerdo
        for patch_id, mask_id in zip(os.listdir(path_left), os.listdir(lesion_path_left)):
            img_path= os.path.join(path_left, patch_id)
            mask_path = os.path.join(lesion_path_left, mask_id)
            for img_path_left, mask_path_left in zip(os.listdir(img_path), os.listdir(mask_path)):
                image_data_left = nib.load(os.path.join(img_path, img_path_left)).get_fdata()
                mask_data_left = nib.load(os.path.join(mask_path, mask_path_left)).get_fdata()

                if (len(image_data_left) > 0 and image_data_left is not []) or (len(mask_data_left) > 0 and mask_data_left is not []):
                    images_left[patient_id].append(image_data_left)
                    mask_left[patient_id].append(mask_data_left)

                    labels_left[patient_id].append(calculate_label(mask_data_left))

        # Carrega as imagens e máscaras do lado direito
        for patch_id, mask_id in zip(os.listdir(path_right), os.listdir(lesion_path_right)):
            img_path = os.path.join(path_right, patch_id)
            mask_path = os.path.join(lesion_path_right, mask_id)
            for img_path_right, mask_path_right in zip(os.listdir(img_path), os.listdir(mask_path)):
                image_data_right = nib.load(os.path.join(img_path, img_path_right)).get_fdata()
                mask_data_right = nib.load(os.path.join(mask_path, mask_path_right)).get_fdata()

                if (len(image_data_right) > 0 and image_data_right is not []) or (len(mask_data_right) > 0 and mask_data_right is not []):
                    image_data_right = np.fliplr(image_data_right)
                    mask_data_right = np.fliplr(mask_data_right)
                    
                    images_right[patient_id].append(image_data_right)
                    mask_right[patient_id].append(mask_data_right)
                    
                    labels_right[patient_id].append(calculate_label(mask_data_right))
        patient_ids.append(patient_id)

    # Estruturas para armazenar os pares de labels
    labels_pair = {}
    for patient_id,_ in zip(labels_left.keys(), labels_right.keys()):
        labels_pair[patient_id] = []
        for label_left, label_right in zip(labels_left[patient_id], labels_right[patient_id]): 
            if label_left == 0 and label_right == 0:
                labels_pair[patient_id].append(0)
            else:
                labels_pair[patient_id].append(1)

    print(f"Total de pacientes: {len(patient_ids)}")
    for patient_id, labels in labels_pair.items():
        print(f"Paciente {patient_id}: Total de pares de recortes: {len(labels)}")

    return images_left, images_right, labels_pair, mask_left, mask_right

# %%
# Função para filtrar as imagens por paciente
def select_by_patients(patients, all_images_original, all_images_opposite, all_labels):
    selected_images_original = {}
    selected_images_opposite = {}
    selected_labels = []
    
    for patient in patients:
        selected_images_original[patient] = []
        selected_images_opposite[patient] = []
        if patient in all_images_original and patient in all_images_opposite:
            selected_images_original[patient].extend(all_images_original[patient])
            selected_images_opposite[patient].extend(all_images_opposite[patient])
            selected_labels.extend(all_labels[patient])
        else:
            print(f"Paciente {patient} não encontrado em uma das listas de imagens.")
    
    return selected_images_original, selected_images_opposite, selected_labels

# %%
# Função para preparar os dados para treino, validação e teste
def prepare_data_for_training_balanced(images_left, images_right, labels_pair, mask_left, mask_right, train_size=0.7, validation_size=0.2, test_size=0.1, augment_factor=1):
    balanced_images_original = {}
    balanced_images_opposite = {}
    balanced_labels = {}
    balanced_mask_original = {}
    balanced_mask_opposite = {}

    for patient_id in images_left:
        class_1_labels = []
        class_0_labels = []
        class_1_left = {}
        class_0_left = {}
        class_1_right = {}
        class_0_right = {}
        class_1_mask_left = {}
        class_0_mask_left = {}
        class_1_mask_right = {}
        class_0_mask_right = {}
        
        class_1_left[patient_id] = []
        class_0_left[patient_id] = []
        class_1_right[patient_id] = []
        class_0_right[patient_id] = []
        class_1_mask_left[patient_id] = []
        class_0_mask_left[patient_id] = []
        class_1_mask_right[patient_id] = []
        class_0_mask_right[patient_id] = []
        index = 0
        
        # Iterar sobre os patches e dividir as classes 0 e 1 com base nas labels\n",
        for label in labels_pair[patient_id]:
            image_left = (images_left[patient_id])[index]
            image_right = (images_right[patient_id])[index]
            mask_image_left = (mask_left[patient_id])[index]
            mask_image_right = (mask_right[patient_id])[index]
            index += 1
            
            if label == 1:
                class_1_labels.append(label)
                class_1_left[patient_id].append(image_left)
                class_1_right[patient_id].append(image_right)
                class_1_mask_left[patient_id].append(mask_image_left)
                class_1_mask_right[patient_id].append(mask_image_right)
            else:
                class_0_labels.append(label)
                class_0_left[patient_id].append(image_left)
                class_0_right[patient_id].append(image_right)
                class_0_mask_left[patient_id].append(mask_image_left)
                class_0_mask_right[patient_id].append(mask_image_right)
        class_1_count = len(class_1_labels)
        print(f"Paciente {patient_id}: Total de pares de recortes com labels 1: {class_1_count}")

        # Fazer undersampling da classe majoritária (label 0) para igualar ao número de exemplos da classe 1\n",
        class_0_count = len(class_0_labels)
        if class_0_count > class_1_count:
            sampled_class_0_slices_left = (class_0_left[patient_id])[:class_1_count]
            sampled_class_0_slices_right = (class_0_right[patient_id])[:class_1_count]
            class_0_original_modified = {}
            class_0_original_modified[patient_id] = []
            class_0_opposite_modified = {}
            class_0_opposite_modified[patient_id] = []
            sampled_class_0_mask_left = (class_0_mask_left[patient_id])[:class_1_count]
            sampled_class_0_mask_right = (class_0_mask_right[patient_id])[:class_1_count]
            class_0_mask_original_modified = {}
            class_0_mask_original_modified[patient_id] = []
            class_0_mask_opposite_modified = {}
            class_0_mask_opposite_modified[patient_id] = []
            
            for left_image, left_mask in zip(sampled_class_0_slices_left, sampled_class_0_mask_left):
                class_0_original_modified[patient_id].append(left_image)
                class_0_mask_original_modified[patient_id].append(left_mask)
            for right_image, right_mask in zip(sampled_class_0_slices_right, sampled_class_0_mask_right):
                class_0_opposite_modified[patient_id].append(right_image)
                class_0_mask_opposite_modified[patient_id].append(right_mask)
            class_0_labels = [0] * class_1_count

        balanced_images_original[patient_id] = list(class_1_left[patient_id]) + list(class_0_original_modified[patient_id])
        balanced_images_opposite[patient_id] = list(class_1_right[patient_id]) + list(class_0_opposite_modified[patient_id])
        balanced_labels[patient_id] = class_1_labels + class_0_labels
        balanced_mask_original[patient_id] = list(class_1_mask_left[patient_id]) + list(class_0_mask_original_modified[patient_id])
        balanced_mask_opposite[patient_id] = list(class_1_mask_right[patient_id]) + list(class_0_mask_opposite_modified[patient_id])
    for patient_id, images in balanced_images_original.items():
        print(f"Paciente {patient_id}: Total de pares de recortes (label 1 + label 0): {len(images)}")
        
    # Separar os dados por conjunto (treino, validação, teste)
    patients = list(set(balanced_labels.keys()))
    train_patients, valtest_patients = train_test_split(patients, train_size = train_size)
    valid_patients, test_patients = train_test_split(valtest_patients, train_size = validation_size / (validation_size + test_size))

    # Apenas para apuração, pois não possuimos classes perfeitamente balanceadas
    train_patients = ['sub-16E03', 'sub-19F09', 'sub-26B09', 'sub-59E09', 'sub-87G01', 'sub-14F04', 'sub-16G09', 'sub-57D04', 'sub-76J09', 'sub-29D03', 'sub-89A03', 'sub-42K06', 'sub-35E12', 'sub-60K04', 'sub-56E13', 'sub-90K10', 'sub-34J06', 'sub-76E02', 'sub-44H05', 'sub-51C05', 'sub-60G06', 'sub-42B05', 'sub-03C08', 'sub-72I02', 'sub-60G13']
    valid_patients = ['sub-54K08', 'sub-41D08', 'sub-71C07', 'sub-02A13', 'sub-83K08', 'sub-85I05', 'sub-86B13', 'sub-52K04']
    test_patients = ['sub-72K02', 'sub-19G04', 'sub-16I12', 'sub-86G08']

    X_train_original, X_train_opposite, y_train = select_by_patients(train_patients, balanced_images_original, balanced_images_opposite, balanced_labels)
    X_val_original, X_val_opposite, y_val = select_by_patients(valid_patients, balanced_images_original, balanced_images_opposite, balanced_labels)
    X_test_original, X_test_opposite, y_test = select_by_patients(test_patients, balanced_images_original, balanced_images_opposite, balanced_labels)
    mask_test_original, mask_test_opposite, _ = select_by_patients(test_patients, balanced_mask_original, balanced_mask_opposite, balanced_labels)

    print(f"Total de pares de recortes no treino ({augment_factor}*{train_patients}) com label 1: {y_train.count(1)}")
    print(f"Total de pares de recortes no treino ({augment_factor}*{train_patients}) com label 0: {y_train.count(0)}")
    print(f"Total de pares de recortes na validação ({augment_factor}*{valid_patients}) com label 1: {y_val.count(1)}")
    print(f"Total de pares de recortes na validação ({augment_factor}*{valid_patients}) com label 0: {y_val.count(0)}")
    print(f"Total de pares de recortes no teste com ({augment_factor}*{test_patients}) label 1: {y_test.count(1)}")
    print(f"Total de pares de recortes no teste com ({augment_factor}*{test_patients}) label 0: {y_test.count(0)}")
    
    return X_train_original, X_train_opposite, X_val_original, X_val_opposite, X_test_original, X_test_opposite, np.array(y_train), np.array(y_val), np.array(y_test), mask_test_original, mask_test_opposite, train_patients, valid_patients, test_patients

# %%
# Função para construir o modelo CNN 2D
def build_cnn_model(input_shape):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3,3), data_format="channels_last", activation='relu', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((3,3)))
    model.add(layers.Dropout(0.5))
    
    model.add(layers.Conv2D(64, (3,3), data_format="channels_last", activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((3,3)))
    model.add(layers.Dropout(0.5))
    
    model.add(layers.Conv2D(128, (3,3), data_format="channels_last", activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((3,3))) 
    model.add(layers.Dropout(0.5)) 
    
    model.add(layers.Conv2D(256, (3,3), padding="same", data_format="channels_last", activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((3,3), padding="same")) 
    model.add(layers.Dropout(0.5))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))

    return model

# %%
# Função para construir a rede siamesa
def build_siamese_model(input_shape):
    input_original = Input(shape=input_shape)
    input_opposite = Input(shape=input_shape)

    # Criar a CNN base compartilhada
    cnn_original = build_cnn_model(input_shape)
    cnn_opposite = build_cnn_model(input_shape)

    # Aplicar a mesma CNN base para ambas as entradas
    output_original = cnn_original(input_original)
    output_opposite = cnn_opposite(input_opposite)

    # Concatenar as duas saídas (Lado esquerdo + Contra-lateral)
    concatenated = layers.Concatenate()([output_original, output_opposite])
    concatenated = layers.BatchNormalization()(concatenated)
    
    output = layers.Dense(1, activation='sigmoid')(concatenated)
    
    siamese_model = Model(inputs=[input_original, input_opposite], outputs=output)
    siamese_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy', metrics.Precision(name="precision"), metrics.Recall(name="recall")])

    return siamese_model

# %%
def plot_training_history(history):
    plt.figure(figsize=(12, 4))

    # Plot Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Graphic')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy Graphic')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# %%
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.show()

# %%
input_folder = 'Contralateral'

# Carregar os dados
X_left, X_right, y, mask_left, mask_right = load_data_with_pairs(input_folder)
# Out:
# Carregamento de arquivos NIfTI...: 100%|██████████| 37/37 [09:48<00:00, 15.91s/it]
# Total de pacientes: 37
# Paciente sub-02A13: Total de pares de recortes: 528
# Paciente sub-03C08: Total de pares de recortes: 484
# Paciente sub-14F04: Total de pares de recortes: 520
# Paciente sub-16E03: Total de pares de recortes: 552
# Paciente sub-16G09: Total de pares de recortes: 516
# Paciente sub-16I12: Total de pares de recortes: 540
# Paciente sub-19F09: Total de pares de recortes: 548
# Paciente sub-19G04: Total de pares de recortes: 496
# Paciente sub-26B09: Total de pares de recortes: 512
# Paciente sub-29D03: Total de pares de recortes: 488
# Paciente sub-34J06: Total de pares de recortes: 564
# Paciente sub-35E12: Total de pares de recortes: 520
# Paciente sub-41D08: Total de pares de recortes: 504
# Paciente sub-42B05: Total de pares de recortes: 528
# Paciente sub-42K06: Total de pares de recortes: 508
# Paciente sub-44H05: Total de pares de recortes: 524
# Paciente sub-51C05: Total de pares de recortes: 548
# Paciente sub-52K04: Total de pares de recortes: 520
# Paciente sub-54K08: Total de pares de recortes: 516
# Paciente sub-56E13: Total de pares de recortes: 516
# Paciente sub-57D04: Total de pares de recortes: 516
# Paciente sub-59E09: Total de pares de recortes: 472
# Paciente sub-60G06: Total de pares de recortes: 536
# Paciente sub-60G13: Total de pares de recortes: 520
# Paciente sub-60K04: Total de pares de recortes: 496
# Paciente sub-71C07: Total de pares de recortes: 472
# Paciente sub-72I02: Total de pares de recortes: 544
# Paciente sub-72K02: Total de pares de recortes: 564
# Paciente sub-76E02: Total de pares de recortes: 560
# Paciente sub-76J09: Total de pares de recortes: 432
# Paciente sub-83K08: Total de pares de recortes: 504
# Paciente sub-85I05: Total de pares de recortes: 532
# Paciente sub-86B13: Total de pares de recortes: 508
# Paciente sub-86G08: Total de pares de recortes: 544
# Paciente sub-87G01: Total de pares de recortes: 528
# Paciente sub-89A03: Total de pares de recortes: 520
# Paciente sub-90K10: Total de pares de recortes: 392

# %%
# Preparar dados para treino, teste e validação
X_train_left, X_train_right, X_valid_left, X_valid_right, X_test_left, X_test_right, y_train, y_valid, y_test, mask_left_test, mask_right_test, train_patients, valid_patients, test_patients = prepare_data_for_training_balanced(X_left, X_right, y, mask_left, mask_right, train_size=0.7, validation_size=0.2, test_size=0.1)

# Crio copias para o print em pdf
train_left = X_train_left
train_right = X_train_right
valid_left = X_valid_left
valid_right = X_valid_right
test_left = X_test_left
test_right = X_test_right

# Adiciono camada de cor
X_train_left = np.array([elemento for lista in X_train_left.values() for elemento in lista])
X_train_left = np.expand_dims(X_train_left, axis=-1)
X_train_right = np.array([elemento for lista in X_train_right.values() for elemento in lista])
X_train_right = np.expand_dims(X_train_right, axis=-1)
X_valid_left = np.array([elemento for lista in X_valid_left.values() for elemento in lista])
X_valid_left = np.expand_dims(X_valid_left, axis=-1)
X_valid_right = np.array([elemento for lista in X_valid_right.values() for elemento in lista])
X_valid_right = np.expand_dims(X_valid_right, axis=-1)
X_test_left = np.array([elemento for lista in X_test_left.values() for elemento in lista])
X_test_left = np.expand_dims(X_test_left, axis=-1)
X_test_right = np.array([elemento for lista in X_test_right.values() for elemento in lista])
X_test_right = np.expand_dims(X_test_right, axis=-1)
# Out:
# Paciente sub-02A13: Total de pares de recortes com labels 1: 28
# Paciente sub-03C08: Total de pares de recortes com labels 1: 52
# Paciente sub-14F04: Total de pares de recortes com labels 1: 9
# Paciente sub-16E03: Total de pares de recortes com labels 1: 58
# Paciente sub-16G09: Total de pares de recortes com labels 1: 75
# Paciente sub-16I12: Total de pares de recortes com labels 1: 21
# Paciente sub-19F09: Total de pares de recortes com labels 1: 128
# Paciente sub-19G04: Total de pares de recortes com labels 1: 20
# Paciente sub-26B09: Total de pares de recortes com labels 1: 94
# Paciente sub-29D03: Total de pares de recortes com labels 1: 14
# Paciente sub-34J06: Total de pares de recortes com labels 1: 22
# Paciente sub-35E12: Total de pares de recortes com labels 1: 35
# Paciente sub-41D08: Total de pares de recortes com labels 1: 50
# Paciente sub-42B05: Total de pares de recortes com labels 1: 75
# Paciente sub-42K06: Total de pares de recortes com labels 1: 46
# Paciente sub-44H05: Total de pares de recortes com labels 1: 120
# Paciente sub-51C05: Total de pares de recortes com labels 1: 68
# Paciente sub-52K04: Total de pares de recortes com labels 1: 102
# Paciente sub-54K08: Total de pares de recortes com labels 1: 100
# Paciente sub-56E13: Total de pares de recortes com labels 1: 45
# Paciente sub-57D04: Total de pares de recortes com labels 1: 47
# Paciente sub-59E09: Total de pares de recortes com labels 1: 25
# Paciente sub-60G06: Total de pares de recortes com labels 1: 97
# Paciente sub-60G13: Total de pares de recortes com labels 1: 87
# Paciente sub-60K04: Total de pares de recortes com labels 1: 24
# Paciente sub-71C07: Total de pares de recortes com labels 1: 17
# Paciente sub-72I02: Total de pares de recortes com labels 1: 29
# Paciente sub-72K02: Total de pares de recortes com labels 1: 73
# Paciente sub-76E02: Total de pares de recortes com labels 1: 28
# Paciente sub-76J09: Total de pares de recortes com labels 1: 36
# Paciente sub-83K08: Total de pares de recortes com labels 1: 46
# Paciente sub-85I05: Total de pares de recortes com labels 1: 36
# Paciente sub-86B13: Total de pares de recortes com labels 1: 20
# Paciente sub-86G08: Total de pares de recortes com labels 1: 52
# Paciente sub-87G01: Total de pares de recortes com labels 1: 55
# Paciente sub-89A03: Total de pares de recortes com labels 1: 20
# Paciente sub-90K10: Total de pares de recortes com labels 1: 31
# Paciente sub-02A13: Total de pares de recortes (label 1 + label 0): 56
# Paciente sub-03C08: Total de pares de recortes (label 1 + label 0): 104
# Paciente sub-14F04: Total de pares de recortes (label 1 + label 0): 18
# Paciente sub-16E03: Total de pares de recortes (label 1 + label 0): 116
# Paciente sub-16G09: Total de pares de recortes (label 1 + label 0): 150
# Paciente sub-16I12: Total de pares de recortes (label 1 + label 0): 42
# Paciente sub-19F09: Total de pares de recortes (label 1 + label 0): 256
# Paciente sub-19G04: Total de pares de recortes (label 1 + label 0): 40
# Paciente sub-26B09: Total de pares de recortes (label 1 + label 0): 188
# Paciente sub-29D03: Total de pares de recortes (label 1 + label 0): 28
# Paciente sub-34J06: Total de pares de recortes (label 1 + label 0): 44
# Paciente sub-35E12: Total de pares de recortes (label 1 + label 0): 70
# Paciente sub-41D08: Total de pares de recortes (label 1 + label 0): 100
# Paciente sub-42B05: Total de pares de recortes (label 1 + label 0): 150
# Paciente sub-42K06: Total de pares de recortes (label 1 + label 0): 92
# Paciente sub-44H05: Total de pares de recortes (label 1 + label 0): 240
# Paciente sub-51C05: Total de pares de recortes (label 1 + label 0): 136
# Paciente sub-52K04: Total de pares de recortes (label 1 + label 0): 204
# Paciente sub-54K08: Total de pares de recortes (label 1 + label 0): 200
# Paciente sub-56E13: Total de pares de recortes (label 1 + label 0): 90
# Paciente sub-57D04: Total de pares de recortes (label 1 + label 0): 94
# Paciente sub-59E09: Total de pares de recortes (label 1 + label 0): 50
# Paciente sub-60G06: Total de pares de recortes (label 1 + label 0): 194
# Paciente sub-60G13: Total de pares de recortes (label 1 + label 0): 174
# Paciente sub-60K04: Total de pares de recortes (label 1 + label 0): 48
# Paciente sub-71C07: Total de pares de recortes (label 1 + label 0): 34
# Paciente sub-72I02: Total de pares de recortes (label 1 + label 0): 58
# Paciente sub-72K02: Total de pares de recortes (label 1 + label 0): 146
# Paciente sub-76E02: Total de pares de recortes (label 1 + label 0): 56
# Paciente sub-76J09: Total de pares de recortes (label 1 + label 0): 72
# Paciente sub-83K08: Total de pares de recortes (label 1 + label 0): 92
# Paciente sub-85I05: Total de pares de recortes (label 1 + label 0): 72
# Paciente sub-86B13: Total de pares de recortes (label 1 + label 0): 40
# Paciente sub-86G08: Total de pares de recortes (label 1 + label 0): 104
# Paciente sub-87G01: Total de pares de recortes (label 1 + label 0): 110
# Paciente sub-89A03: Total de pares de recortes (label 1 + label 0): 40
# Paciente sub-90K10: Total de pares de recortes (label 1 + label 0): 62
# Total de pares de recortes no treino (1*['sub-16E03', 'sub-19F09', 'sub-26B09', 'sub-59E09', 'sub-87G01', 'sub-14F04', 'sub-16G09', 'sub-57D04', 'sub-76J09', 'sub-29D03', 'sub-89A03', 'sub-42K06', 'sub-35E12', 'sub-60K04', 'sub-56E13', 'sub-90K10', 'sub-34J06', 'sub-76E02', 'sub-44H05', 'sub-51C05', 'sub-60G06', 'sub-42B05', 'sub-03C08', 'sub-72I02', 'sub-60G13']) com label 1: 1320
# Total de pares de recortes no treino (1*['sub-16E03', 'sub-19F09', 'sub-26B09', 'sub-59E09', 'sub-87G01', 'sub-14F04', 'sub-16G09', 'sub-57D04', 'sub-76J09', 'sub-29D03', 'sub-89A03', 'sub-42K06', 'sub-35E12', 'sub-60K04', 'sub-56E13', 'sub-90K10', 'sub-34J06', 'sub-76E02', 'sub-44H05', 'sub-51C05', 'sub-60G06', 'sub-42B05', 'sub-03C08', 'sub-72I02', 'sub-60G13']) com label 0: 1320
# Total de pares de recortes na validação (1*['sub-54K08', 'sub-41D08', 'sub-71C07', 'sub-02A13', 'sub-83K08', 'sub-85I05', 'sub-86B13', 'sub-52K04']) com label 1: 399
# Total de pares de recortes na validação (1*['sub-54K08', 'sub-41D08', 'sub-71C07', 'sub-02A13', 'sub-83K08', 'sub-85I05', 'sub-86B13', 'sub-52K04']) com label 0: 399
# Total de pares de recortes no teste com (1*['sub-72K02', 'sub-19G04', 'sub-16I12', 'sub-86G08']) label 1: 166
# Total de pares de recortes no teste com (1*['sub-72K02', 'sub-19G04', 'sub-16I12', 'sub-86G08']) label 0: 166

# %%
# Construir e compilar o modelo CNN
input_shape = (X_train_left[0].shape)

siamese_model = build_siamese_model(input_shape)
siamese_model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 60, 60, 1)]          0         []
#
#  input_2 (InputLayer)        [(None, 60, 60, 1)]          0         []
#
#  sequential (Sequential)     (None, 256)                  455552    ['input_1[0][0]']
#
#  sequential_1 (Sequential)   (None, 256)                  455552    ['input_2[0][0]']
#
#  concatenate (Concatenate)   (None, 512)                  0         ['sequential[0][0]',
#                                                                      'sequential_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 512)                  2048      ['concatenate[0][0]']
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1)                    513       ['batch_normalization_8[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 913665 (3.49 MB)
# Trainable params: 910721 (3.47 MB)
# Non-trainable params: 2944 (11.50 KB)
# __________________________________________________________________________________________________

# %%
# Adicionar o callback EarlyStopping e low rate scheduler
# early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Salvar a melhor epoca
checkpoint = callbacks.ModelCheckpoint('best_model.h5', monitor='val_loss',  save_best_only=True,  save_weights_only=True, mode='min')

# Treinamento do modelo siames
history = siamese_model.fit([X_train_left, X_train_right], y_train, validation_data=([X_valid_left, X_valid_right], y_valid), batch_size=64, epochs=300, callbacks=[checkpoint])
# Out:
# Epoch 1/300
# WARNING:tensorflow:From c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Gabriel Panza\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 42/42 [==============================] - 9s 110ms/step - loss: 0.8768 - accuracy: 0.4913 - precision: 0.4915 - recall: 0.5023 - val_loss: 0.6886 - val_accuracy: 0.4987 - val_precision: 0.4994 - val_recall: 0.9900
# Epoch 2/300
# 42/42 [==============================] - 4s 87ms/step - loss: 0.8236 - accuracy: 0.5148 - precision: 0.5153 - recall: 0.4985 - val_loss: 0.6867 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 3/300
# 42/42 [==============================] - 3s 80ms/step - loss: 0.7711 - accuracy: 0.5561 - precision: 0.5565 - recall: 0.5523 - val_loss: 0.6873 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/300
# 42/42 [==============================] - 3s 80ms/step - loss: 0.7552 - accuracy: 0.5549 - precision: 0.5562 - recall: 0.5432 - val_loss: 0.6876 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 5/300
# 42/42 [==============================] - 3s 77ms/step - loss: 0.7680 - accuracy: 0.5455 - precision: 0.5477 - recall: 0.5220 - val_loss: 0.7223 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch
300
# 42/42 [==============================] - 4s 89ms/step - loss: 0.6208 - accuracy: 0.6686 - precision: 0.6718 - recall: 0.6591 - val_loss: 0.5820 - val_accuracy: 0.6679 - val_precision: 0.6259 - val_recall: 0.8346
# Epoch 37/300
# 42/42 [==============================] - 4s 87ms/step - loss: 0.6260 - accuracy: 0.6803 - precision: 0.6825 - recall: 0.6742 - val_loss: 0.5770 - val_accuracy: 0.6930 - val_precision: 0.6492 - val_recall: 0.8396
# Epoch 38/300
# 42/42 [==============================] - 4s 85ms/step - loss: 0.6080 - accuracy: 0.6879 - precision: 0.6962 - recall: 0.6667 - val_loss: 0.5651 - val_accuracy: 0.7080 - val_precision: 0.6660 - val_recall: 0.8346
# Epoch 39/300
# 42/42 [==============================] - 4s 95ms/step - loss: 0.5963 - accuracy: 0.6754 - precision: 0.6758 - recall: 0.6742 - val_loss: 0.5620 - val_accuracy: 0.7118 - val_precision: 0.6757 - val_recall: 0.8145
# Epoch 40/300
# 42/42 [==============================] - 4s 88ms/step - loss: 0.6107 - accuracy: 0.6746 - precision: 0.6808 - recall: 0.6576 - val_loss: 0.5531 - val_accuracy: 0.7143 - val_precision: 0.6727 - val_recall: 0.8346
# Epoch 41/300
# 42/42 [==============================] - 4s 88ms/step - loss: 0.6077 - accuracy: 0.6811 - precision: 0.6838 - recall: 0.6735 - val_loss: 0.5456 - val_accuracy: 0.7218 - val_precision: 0.6832 - val_recall: 0.8271
# Epoch 42/300
# 42/42 [==============================] - 4s 84ms/step - loss: 0.6191 - accuracy: 0.6727 - precision: 0.6807 - recall: 0.6508 - val_loss: 0.5415 - val_accuracy: 0.7256 - val_precision: 0.6822 - val_recall: 0.8446
# Epoch 43/300
# 42/42 [==============================] - 4s 85ms/step - loss: 0.5925 - accuracy: 0.6814 - precision: 0.6841 - recall: 0.6742 - val_loss: 0.5409 - val_accuracy: 0.7306 - val_precision: 0.6893 - val_recall: 0.8396
# Epoch 44/300
# 42/42 [==============================] - 4s 86ms/step - loss: 0.5899 - accuracy: 0.6883 - precision: 0.6949 - recall: 0.6712 - val_loss: 0.5314 - val_accuracy: 0.7368 - val_precision: 0.6940 - val_recall: 0.8471
# Epoch 45/300
# 42/42 [==============================] - 4s 88ms/step - loss: 0.5796 - accuracy: 0.6951 - precision: 0.7055 - recall: 0.6697 - val_loss: 0.5415 - val_accuracy: 0.7318 - val_precision: 0.6892 - val_recall: 0.8446
# Epoch 46/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.5734 - accuracy: 0.6973 - precision: 0.7008 - recall: 0.6886 - val_loss: 0.5368 - val_accuracy: 0.7343 - val_precision: 0.7019 - val_recall: 0.8145
# Epoch 47/300
# 42/42 [==============================] - 4s 88ms/step - loss: 0.5903 - accuracy: 0.7015 - precision: 0.7049 - recall: 0.6932 - val_loss: 0.5390 - val_accuracy: 0.7281 - val_precision: 0.6857 - val_recall: 0.8421
# Epoch 48/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.5903 - accuracy: 0.6879 - precision: 0.6978 - recall: 0.6629 - val_loss: 0.5366 - val_accuracy: 0.7331 - val_precision: 0.6954 - val_recall: 0.8296
# Epoch 49/300
# 42/42 [==============================] - 4s 93ms/step - loss: 0.5819 - accuracy: 0.6981 - precision: 0.7094 - recall: 0.6712 - val_loss: 0.5271 - val_accuracy: 0.7419 - val_precision: 0.7058 - val_recall: 0.8296
# Epoch 50/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.5838 - accuracy: 0.7019 - precision: 0.7042 - recall: 0.6962 - val_loss: 0.5256 - val_accuracy: 0.7506 - val_precision: 0.7193 - val_recall: 0.8221
# Epoch 51/300
# 42/42 [==============================] - 4s 96ms/step - loss: 0
300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2628 - accuracy: 0.8920 - precision: 0.9002 - recall: 0.8818 - val_loss: 0.8294 - val_accuracy: 0.7331 - val_precision: 0.7031 - val_recall: 0.8070
# Epoch 253/300
# 42/42 [==============================] - 4s 94ms/step - loss: 0.2827 - accuracy: 0.8761 - precision: 0.8882 - recall: 0.8606 - val_loss: 0.8543 - val_accuracy: 0.7093 - val_precision: 0.6956 - val_recall: 0.7444
# Epoch 254/300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2651 - accuracy: 0.8867 - precision: 0.8900 - recall: 0.8826 - val_loss: 0.8559 - val_accuracy: 0.7055 - val_precision: 0.6934 - val_recall: 0.7368
# Epoch 255/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.2682 - accuracy: 0.8780 - precision: 0.8741 - recall: 0.8833 - val_loss: 0.7754 - val_accuracy: 0.7594 - val_precision: 0.7265 - val_recall: 0.8321
# Epoch 256/300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2615 - accuracy: 0.8939 - precision: 0.8951 - recall: 0.8924 - val_loss: 0.8011 - val_accuracy: 0.7218 - val_precision: 0.7073 - val_recall: 0.7569
# Epoch 257/300
# 42/42 [==============================] - 4s 92ms/step - loss: 0.2548 - accuracy: 0.8928 - precision: 0.8973 - recall: 0.8871 - val_loss: 0.7967 - val_accuracy: 0.7256 - val_precision: 0.7093 - val_recall: 0.7644
# Epoch 258/300
# 42/42 [==============================] - 4s 93ms/step - loss: 0.2593 - accuracy: 0.8936 - precision: 0.8987 - recall: 0.8871 - val_loss: 0.8312 - val_accuracy: 0.7256 - val_precision: 0.7074 - val_recall: 0.7694
# Epoch 259/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.2541 - accuracy: 0.8913 - precision: 0.8970 - recall: 0.8841 - val_loss: 0.8390 - val_accuracy: 0.7143 - val_precision: 0.6948 - val_recall: 0.7644
# Epoch 260/300
# 42/42 [==============================] - 4s 89ms/step - loss: 0.2446 - accuracy: 0.8996 - precision: 0.9080 - recall: 0.8894 - val_loss: 0.8540 - val_accuracy: 0.7231 - val_precision: 0.7041 - val_recall: 0.7694
# Epoch 261/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.2588 - accuracy: 0.8894 - precision: 0.8954 - recall: 0.8818 - val_loss: 0.8496 - val_accuracy: 0.7431 - val_precision: 0.7109 - val_recall: 0.8195
# Epoch 262/300
# 42/42 [==============================] - 4s 88ms/step - loss: 0.2768 - accuracy: 0.8799 - precision: 0.8885 - recall: 0.8689 - val_loss: 0.8886 - val_accuracy: 0.7030 - val_precision: 0.6841 - val_recall: 0.7544
# Epoch 263/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.2511 - accuracy: 0.8924 - precision: 0.8948 - recall: 0.8894 - val_loss: 0.8375 - val_accuracy: 0.7318 - val_precision: 0.6846 - val_recall: 0.8596
# Epoch 264/300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2485 - accuracy: 0.8973 - precision: 0.9050 - recall: 0.8879 - val_loss: 0.8346 - val_accuracy: 0.7293 - val_precision: 0.6943 - val_recall: 0.8195
# Epoch 265/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.2479 - accuracy: 0.8966 - precision: 0.9030 - recall: 0.8886 - val_loss: 0.8458 - val_accuracy: 0.7218 - val_precision: 0.6863 - val_recall: 0.8170
# Epoch 266/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.2528 - accuracy: 0.8947 - precision: 0.8983 - recall: 0.8902 - val_loss: 0.8980 - val_accuracy: 0.7093 - val_precision: 0.6902 - val_recall: 0.7594
# Epoch 267/300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2566 - accuracy: 0.8909 - precision: 0.8909 - recall: 0.8909 - val_loss: 0.9131 - val_accuracy: 0.7080 - val_precision: 0.6904 - val_recall: 0.7544
# Epoch 268/300
# 42/42 [==============================] - 4s 92ms/step - loss: 0.2460 - accuracy: 0.8913 - precision: 0.8946 - recall: 0.8871 - val_loss: 0.8546 - val_accuracy: 0.7243 - val_precision: 0.7048 - val_recall: 0.7719
# Epoch 269/300
# 42/42 [==============================] - 4s 93ms/step - loss: 0.2637 - accuracy: 0.8890 - precision: 0.9009 - recall: 0.8742 - val_loss: 0.8135 - val_accuracy: 0.7469 - val_precision: 0.7031 - val_recall: 0.8546
# Epoch 270/300
# 42/42 [==============================] - 4s 89ms/step - loss: 0.2493 - accuracy: 0.8955 - precision: 0.9003 - recall: 0.8894 - val_loss: 0.8196 - val_accuracy: 0.7318 - val_precision: 0.7098 - val_recall: 0.7845
# Epoch 271/300
# 42/42 [==============================] - 4s 89ms/step - loss: 0.2495 - accuracy: 0.8898 - precision: 0.8967 - recall: 0.8811 - val_loss: 0.8025 - val_accuracy: 0.7594 - val_precision: 0.7152 - val_recall: 0.8622
# Epoch 272/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.2386 - accuracy: 0.8985 - precision: 0.9015 - recall: 0.8947 - val_loss: 0.8451 - val_accuracy: 0.7318 - val_precision: 0.6989 - val_recall: 0.8145
# Epoch 273/300
# 42/42 [==============================] - 4s 89ms/step - loss: 0.2495 - accuracy: 0.8932 - precision: 0.9005 - recall: 0.8841 - val_loss: 0.8520 - val_accuracy: 0.7281 - val_precision: 0.6978 - val_recall: 0.8045
# Epoch 274/300
# 42/42 [==============================] - 4s 88ms/step - loss: 0.2392 - accuracy: 0.8989 - precision: 0.8998 - recall: 0.8977 - val_loss: 0.8184 - val_accuracy: 0.7368 - val_precision: 0.7059 - val_recall: 0.8120
# Epoch 275/300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2536 - accuracy: 0.8909 - precision: 0.8969 - recall: 0.8833 - val_loss: 0.8936 - val_accuracy: 0.7218 - val_precision: 0.7025 - val_recall: 0.7694
# Epoch 276/300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2407 - accuracy: 0.9023 - precision: 0.9078 - recall: 0.8955 - val_loss: 0.8316 - val_accuracy: 0.7607 - val_precision: 0.7097 - val_recall: 0.8822
# Epoch 277/300
# 42/42 [==============================] - 4s 93ms/step - loss: 0.2474 - accuracy: 0.8970 - precision: 0.9006 - recall: 0.8924 - val_loss: 0.8364 - val_accuracy: 0.7419 - val_precision: 0.6926 - val_recall: 0.8697
# Epoch 278/300
# 42/42 [==============================] - 4s 95ms/step - loss: 0.2495 - accuracy: 0.8977 - precision: 0.8995 - recall: 0.8955 - val_loss: 0.8451 - val_accuracy: 0.7381 - val_precision: 0.7102 - val_recall: 0.8045
# Epoch 279/300
# 42/42 [==============================] - 4s 93ms/step - loss: 0.2318 - accuracy: 0.9038 - precision: 0.9138 - recall: 0.8917 - val_loss: 0.8202 - val_accuracy: 0.7406 - val_precision: 0.6992 - val_recall: 0.8446
# Epoch 280/300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2386 - accuracy: 0.9019 - precision: 0.9103 - recall: 0.8917 - val_loss: 0.8502 - val_accuracy: 0.7218 - val_precision: 0.6920 - val_recall: 0.7995
# Epoch 281/300
# 42/42 [==============================] - 4s 90ms/step - loss: 0.2353 - accuracy: 0.9011 - precision: 0.8996 - recall: 0.9030 - val_loss: 0.8656 - val_accuracy: 0.7256 - val_precision: 0.7000 - val_recall: 0.7895
# Epoch 282/300
# 42/42 [==============================] - 4s 91ms/step - loss: 0.2372 - accuracy: 0.9015 - precision: 0.9015 - recall: 0.9015 - val_loss: 0.8972 - val_accuracy: 0.7155 - val_precision: 0.6903 - val_recall: 0.7820
# Epoch 283/300
# 42/42 [==============================] - 4s 92ms/step - loss: 0
# Epoch 297/300
# 42/42 [==============================] - 4s 102ms/step - loss: 0.2377 - accuracy: 0.9057 - precision: 0.9085 - recall: 0.9023 - val_loss: 0.9338 - val_accuracy: 0.6980 - val_precision: 0.6667 - val_recall: 0.7920
# Epoch 298/300
# 42/42 [==============================] - 5s 109ms/step - loss: 0.2210 - accuracy: 0.9083 - precision: 0.9102 - recall: 0.9061 - val_loss: 0.9520 - val_accuracy: 0.6880 - val_precision: 0.6603 - val_recall: 0.7744
# Epoch 299/300
# 42/42 [==============================] - 5s 128ms/step - loss: 0.2303 - accuracy: 0.9083 - precision: 0.9108 - recall: 0.9053 - val_loss: 0.9336 - val_accuracy: 0.6967 - val_precision: 0.6718 - val_recall: 0.7694
# Epoch 300/300
# 42/42 [==============================] - 4s 100ms/step - loss: 0.2171 - accuracy: 0.9155 - precision: 0.9249 - recall: 0.9045 - val_loss: 0.9106 - val_accuracy: 0.7118 - val_precision: 0.6786 - val_recall: 0.8045

# %%
# Carregando pesos da melhor época
siamese_model.load_weights('best_model.h5')

# Avaliar o modelo no treino
y_pred_train = (siamese_model.predict([X_train_left, X_train_right]) >=  0.5)

# Avaliar o modelo na validação
y_pred_valid = (siamese_model.predict([X_valid_left, X_valid_right]) >=  0.5)

# Avaliar o modelo no teste
y_pred = (siamese_model.predict([X_test_left, X_test_right]) >=  0.5)

# Calcule a curva precision-recall
precision, recall, _ = precision_recall_curve(y_test, y_pred)

# Calcule a AUC precision-recall
auc_pr = auc(recall, precision)

# Plote a curva precision-recall
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f'AUC = {auc_pr:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.grid(alpha=0.5)
plt.show()

# Gerar o relatório de classificação
print(classification_report(y_test, y_pred))
# Out:
# 83/83 [==============================] - 2s 16ms/step
# 25/25 [==============================] - 0s 15ms/step
# 11/11 [==============================] - 0s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76       166
#            1       0.78      0.70      0.74       166
#
#     accuracy                           0.75       332
#    macro avg       0.76      0.75      0.75       332
# weighted avg       0.76      0.75      0.75       332

# %%
# Gerar a matriz de confusão
plot_confusion_matrix(y_test, y_pred)

# %%
# Plotar o histórico do treinamento
plot_training_history(history)

# %%
def plot_classified_images_to_pdf(
    test_left, test_right, y_test, y_pred, mask_left_test, mask_right_test,
    condition, pdf_path, description):
    """
    Função genérica para plotar e salvar imagens classificadas em um PDF.

    Args:
        test_left (dict): Imagens MRI do lado esquerdo.
        test_right (dict): Imagens MRI do lado direito.
        y_test (list): Labels verdadeiros.
        y_pred (list): Labels preditos.
        mask_left_test (dict): Máscaras do lado esquerdo.
        mask_right_test (dict): Máscaras do lado direito.
        condition (callable): Função que define a condição para inclusão.
        pdf_path (str): Caminho do arquivo PDF para salvar as imagens.
        description (str): Descrição do conjunto de dados (e.g., "FN", "FP").
    """
    with PdfPages(pdf_path) as pdf:
        cont = 0
        for patient in test_left.keys():
            for i in range(len(test_left[patient])):
                label_pred = "Sim" if y_pred[cont] == 1 else "Não"
                label_verd = "Sim" if y_test[cont] == 1 else "Não"
                
                # Verificar condição de filtro
                if condition(label_verd, label_pred):
                    # Exibe progresso
                    print(f"Processando imagem {cont + 1} de {len(y_pred)} ({description})")

                    # Configuração da figura
                    fig, axs = plt.subplots(2, 2, figsize=(4, 4))

                    # Exibe as imagens
                    axs[0, 0].imshow(test_left[patient][i], cmap='gray')
                    axs[0, 0].set_title(f'{patient}-MRI E-{i}')
                    axs[0, 0].axis('off')

                    axs[1, 0].imshow(mask_left_test[patient][i], cmap='gray')
                    axs[1, 0].set_title(f'{patient}-Mask E-{i}')
                    axs[1, 0].axis('off')

                    axs[0, 1].imshow(test_right[patient][i], cmap='gray')
                    axs[0, 1].set_title(f'{patient}-MRI D-{i}')
                    axs[0, 1].axis('off')

                    axs[1, 1].imshow(mask_right_test[patient][i], cmap='gray')
                    axs[1, 1].set_title(f'{patient}-Mask D-{i}')
                    axs[1, 1].axis('off')

                    # Adiciona a figura atual ao PDF
                    pdf.savefig(fig)
                    plt.close(fig)

                cont += 1
        
        print(f"As imagens foram salvas no arquivo PDF '{pdf_path}' com sucesso.")

# Condições de Filtro
def condition_fn(label_verd, label_pred):
    return label_pred == "Não" and label_verd == "Sim"

def condition_fp(label_verd, label_pred):
    return label_pred == "Sim" and label_verd == "Não"

def condition_tn(label_verd, label_pred):
    return label_pred == "Não" and label_verd == "Não"

def condition_tp(label_verd, label_pred):
    return label_pred == "Sim" and label_verd == "Sim"

# Chamada das Funções
plot_classified_images_to_pdf(
    test_left, test_right, y_test, y_pred, mask_left_test, mask_right_test,
    condition_fn, 'Pdf_CNN/Pacientes_Conjunto_Teste_FN.pdf', 'FN')

plot_classified_images_to_pdf(
    test_left, test_right, y_test, y_pred, mask_left_test, mask_right_test,
    condition_fp, 'Pdf_CNN/Pacientes_Conjunto_Teste_FP.pdf', 'FP')

plot_classified_images_to_pdf(
    test_left, test_right, y_test, y_pred, mask_left_test, mask_right_test,
    condition_tn, 'Pdf_CNN/Pacientes_Conjunto_Teste_TN.pdf', 'TN')

plot_classified_images_to_pdf(
    test_left, test_right, y_test, y_pred, mask_left_test, mask_right_test,
    condition_tp, 'Pdf_CNN/Pacientes_Conjunto_Teste_TP.pdf', 'TP')
# Out:
# Processando imagem 5 de 332 (FN)
# Processando imagem 7 de 332 (FN)
# Processando imagem 22 de 332 (FN)
# Processando imagem 24 de 332 (FN)
# Processando imagem 26 de 332 (FN)
# Processando imagem 28 de 332 (FN)
# Processando imagem 30 de 332 (FN)
# Processando imagem 32 de 332 (FN)
# Processando imagem 34 de 332 (FN)
# Processando imagem 36 de 332 (FN)
# Processando imagem 38 de 332 (FN)
# Processando imagem 40 de 332 (FN)
# Processando imagem 42 de 332 (FN)
# Processando imagem 44 de 332 (FN)
# Processando imagem 46 de 332 (FN)
# Processando imagem 48 de 332 (FN)
# Processando imagem 50 de 332 (FN)
# Processando imagem 52 de 332 (FN)
# Processando imagem 54 de 332 (FN)
# Processando imagem 56 de 332 (FN)
# Processando imagem 58 de 332 (FN)
# Processando imagem 60 de 332 (FN)
# Processando imagem 62 de 332 (FN)
# Processando imagem 64 de 332 (FN)
# Processando imagem 66 de 332 (FN)
# Processando imagem 68 de 332 (FN)
# Processando imagem 70 de 332 (FN)
# Processando imagem 72 de 332 (FN)
# Processando imagem 189 de 332 (FN)
# Processando imagem 190 de 332 (FN)
# Processando imagem 191 de 332 (FN)
# Processando imagem 192 de 332 (FN)
# Processando imagem 193 de 332 (FN)
# Processando imagem 194 de 332 (FN)
# Processando imagem 195 de 332 (FN)
# Processando imagem 196 de 332 (FN)
# Processando imagem 229 de 332 (FN)
# Processando imagem 230 de 332 (FN)
# Processando imagem 231 de 332 (FN)
# Processando imagem 232 de 332 (FN)
# Processando imagem 233 de 332 (FN)
# Processando imagem 234 de 332 (FN)
# Processando imagem 235 de 332 (FN)
# Processando imagem 236 de 332 (FN)
# Processando imagem 237 de 332 (FN)
# Processando imagem 277 de 332 (FN)
# Processando imagem 278 de 332 (FN)
# Processando imagem 279 de 332 (FN)
# Processando imagem 280 de 332 (FN)
# As imagens foram salvas no arquivo PDF 'Pdf_CNN/Pacientes_Conjunto_Teste_FN.pdf' com sucesso.
# Processando imagem 85 de 332 (FP)
# Processando imagem 120 de 332 (FP)
# Processando imagem 124 de 332 (FP)
# Processando imagem 125 de 332 (FP)
# Processando imagem 128 de 332 (FP)
# Processando imagem 129 de 332 (FP)
# Processando imagem 132 de 332 (FP)
# Processando imagem 133 de 332 (FP)
# Processando imagem 136 de 332 (FP)
# Processando imagem 137 de 332 (FP)
# Processando imagem 140 de 332 (FP)
# Processando imagem 141 de 332 (FP)
# Processando imagem 144 de 332 (FP)
# Processando imagem 145 de 332 (FP)
# Processando imagem 169 de 332 (FP)
# Processando imagem 170 de 332 (FP)
# Processando imagem 173 de 332 (FP)
# Processando imagem 174 de 332 (FP)
# Processando imagem 177 de 332 (FP)
# Processando imagem 178 de 332 (FP)
# Processando imagem 181 de 332 (FP)
# Processando imagem 182 de 332 (FP)
# Processando imagem 185 de 332 (FP)
# Processando imagem 186 de 332 (FP)
# Processando imagem 304 de 332 (FP)
# Processando imagem 307 de 332 (FP)
# Processando imagem 313 de 332 (FP)
# Processando imagem 316 de 332 (FP)
# Processando imagem 319 de 332 (FP)
# Processando imagem 322 de 332 (FP)
# Processando imagem 325 de 332 (FP)
# Processando imagem 328 de 332 (FP)
# Processando imagem 331 de 332 (FP)
# As imagens foram salvas no arquivo PDF 'Pdf_CNN/Pacientes_Conjunto_Teste_FP.pdf' com sucesso.
# Processando imagem 74 de 332 (TN)
# Processando imagem 75 de 332 (TN)
# Processando imagem 76 de 332 (TN)
# Processando imagem 77 de 332 (TN)
# Processando imagem 78 de 332 (TN)
# Processando imagem 79 de 332 (TN)
# Processando imagem 80 de 332 (TN)
# Processando imagem 81 de 332 (TN)
# Processando imagem 82 de 332 (TN)
# Processando imagem 83 de 332 (TN)
# Processando imagem 84 de 332 (TN)
# Processando imagem 86 de 332 (TN)
# Processando imagem 87 de 332 (TN)
# Processando imagem 88 de 332 (TN)
# Processando imagem 286 de 332 (TN)
# Processando imagem 287 de 332 (TN)
# Processando imagem 288 de 332 (TN)
# Processando imagem 289 de 332 (TN)
# Processando imagem 290 de 332 (TN)
# Processando imagem 291 de 332 (TN)
# Processando imagem 292 de 332 (TN)
# Processando imagem 293 de 332 (TN)
# Processando imagem 294 de 332 (TN)
# Processando imagem 295 de 332 (TN)
# Processando imagem 296 de 332 (TN)
# Processando imagem 297 de 332 (TN)
# Processando imagem 298 de 332 (TN)
# Processando imagem 299 de 332 (TN)
# Processando imagem 300 de 332 (TN)
# Processando imagem 301 de 332 (TN)
# Processando imagem 302 de 332 (TN)
# Processando imagem 303 de 332 (TN)
# Processando imagem 305 de 332 (TN)
# Processando imagem 306 de 332 (TN)
# Processando imagem 308 de 332 (TN)
# Processando imagem 309 de 332 (TN)
# Processando imagem 310 de 332 (TN)
# Processando imagem 311 de 332 (TN)
# Processando imagem 312 de 332 (TN)
# Processando imagem 314 de 332 (TN)
# Processando imagem 315 de 332 (TN)
# Processando imagem 317 de 332 (TN)
# Processando imagem 318 de 332 (TN)
# Processando imagem 320 de 332 (TN)
# Processando imagem 321 de 332 (TN)
# Processando imagem 323 de 332 (TN)
# Processando imagem 324 de 332 (TN)
# Processando imagem 326 de 332 (TN)
# Processando imagem 327 de 332 (TN)
# Processando imagem 329 de 332 (TN)
# Processando imagem 330 de 332 (TN)
# Processando imagem 332 de 332 (TN)
# As imagens foram salvas no arquivo PDF 'Pdf_CNN/Pacientes_Conjunto_Teste_TN.pdf' com sucesso.
# Processando imagem 1 de 332 (TP)
# Processando imagem 2 de 332 (TP)
# Processando imagem 3 de 332 (TP)
# Processando imagem 4 de 332 (TP)
# Processando imagem 6 de 332 (TP)
# Processando imagem 8 de 332 (TP)
# Processando imagem 9 de 332 (TP)
# Processando imagem 10 de 332 (TP)
# Processando imagem 11 de 332 (TP)
# Processando imagem 12 de 332 (TP)
# Processando imagem 13 de 332 (TP)
# Processando imagem 14 de 332 (TP)
# Processando imagem 15 de 332 (TP)
# Processando imagem 16 de 332 (TP)
# Processando imagem 17 de 332 (TP)
# Processando imagem 18 de 332 (TP)
# Processando imagem 19 de 332 (TP)
# Processando imagem 20 de 332 (TP)
# Processando imagem 21 de 332 (TP)
# Processando imagem 23 de 332 (TP)
# Processando imagem 25 de 332 (TP)
# Processando imagem 27 de 332 (TP)
# Processando imagem 29 de 332 (TP)
# Processando imagem 31 de 332 (TP)
# Processando imagem 33 de 332 (TP)
# Processando imagem 35 de 332 (TP)
# Processando imagem 37 de 332 (TP)
# Processando imagem 39 de 332 (TP)
# Processando imagem 41 de 332 (TP)
# Processando imagem 43 de 332 (TP)
# Processando imagem 45 de 332 (TP)
# Processando imagem 47 de 332 (TP)
# Processando imagem 49 de 332 (TP)
# Processando imagem 51 de 332 (TP)
# Processando imagem 53 de 332 (TP)
# Processando imagem 55 de 332 (TP)
# Processando imagem 57 de 332 (TP)
# Processando imagem 59 de 332 (TP)
# Processando imagem 61 de 332 (TP)
# Processando imagem 63 de 332 (TP)
# Processando imagem 65 de 332 (TP)
# Processando imagem 67 de 332 (TP)
# Processando imagem 69 de 332 (TP)
# Processando imagem 71 de 332 (TP)
# Processando imagem 73 de 332 (TP)
# Processando imagem 147 de 332 (TP)
# Processando imagem 148 de 332 (TP)
# Processando imagem 149 de 332 (TP)
# Processando imagem 150 de 332 (TP)
# Processando imagem 151 de 332 (TP)
# Processando imagem 152 de 332 (TP)
# Processando imagem 153 de 332 (TP)
# Processando imagem 154 de 332 (TP)
# Processando imagem 155 de 332 (TP)
# Processando imagem 156 de 332 (TP)
# Processando imagem 157 de 332 (TP)
# Processando imagem 158 de 332 (TP)
# Processando imagem 159 de 332 (TP)
# Processando imagem 160 de 332 (TP)
# Processando imagem 161 de 332 (TP)
# Processando imagem 162 de 332 (TP)
# Processando imagem 163 de 332 (TP)
# Processando imagem 164 de 332 (TP)
# Processando imagem 165 de 332 (TP)
# Processando imagem 166 de 332 (TP)
# Processando imagem 187 de 332 (TP)
# Processando imagem 188 de 332 (TP)
# Processando imagem 197 de 332 (TP)
# Processando imagem 198 de 332 (TP)
# Processando imagem 199 de 332 (TP)
# Processando imagem 200 de 332 (TP)
# Processando imagem 201 de 332 (TP)
# Processando imagem 202 de 332 (TP)
# Processando imagem 203 de 332 (TP)
# Processando imagem 204 de 332 (TP)
# Processando imagem 205 de 332 (TP)
# Processando imagem 206 de 332 (TP)
# Processando imagem 207 de 332 (TP)
# Processando imagem 238 de 332 (TP)
# Processando imagem 239 de 332 (TP)
# Processando imagem 240 de 332 (TP)
# Processando imagem 241 de 332 (TP)
# Processando imagem 242 de 332 (TP)
# Processando imagem 243 de 332 (TP)
# Processando imagem 244 de 332 (TP)
# Processando imagem 245 de 332 (TP)
# Processando imagem 246 de 332 (TP)
# Processando imagem 247 de 332 (TP)
# Processando imagem 248 de 332 (TP)
# Processando imagem 249 de 332 (TP)
# Processando imagem 250 de 332 (TP)
# Processando imagem 251 de 332 (TP)
# Processando imagem 252 de 332 (TP)
# Processando imagem 253 de 332 (TP)
# Processando imagem 254 de 332 (TP)
# Processando imagem 255 de 332 (TP)
# Processando imagem 256 de 332 (TP)
# Processando imagem 257 de 332 (TP)
# Processando imagem 258 de 332 (TP)
# Processando imagem 259 de 332 (TP)
# Processando imagem 260 de 332 (TP)
# Processando imagem 261 de 332 (TP)
# Processando imagem 262 de 332 (TP)
# Processando imagem 263 de 332 (TP)
# Processando imagem 264 de 332 (TP)
# Processando imagem 265 de 332 (TP)
# Processando imagem 266 de 332 (TP)
# Processando imagem 267 de 332 (TP)
# Processando imagem 268 de 332 (TP)
# Processando imagem 269 de 332 (TP)
# Processando imagem 270 de 332 (TP)
# Processando imagem 271 de 332 (TP)
# Processando imagem 272 de 332 (TP)
# Processando imagem 273 de 332 (TP)
# Processando imagem 274 de 332 (TP)
# Processando imagem 275 de 332 (TP)
# Processando imagem 276 de 332 (TP)
# As imagens foram salvas no arquivo PDF 'Pdf_CNN/Pacientes_Conjunto_Teste_TP.pdf' com sucesso.
